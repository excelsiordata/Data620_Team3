# %%
import matlab as ml
import pandas as pd
import numpy as np
import networkx as nx
from networkx import *
from matlab import *
from urllib2 import *
from community import *
import re
from collections import Counter

# %%
# use this version or GML file will fail to tokenize (Formatting issue) ->    pip install networkx==1.9.1

url = "http://networkdata.ics.uci.edu/data/football/football.gml"
handle = urlopen(url)
G = nx.read_gml(handle)
nx.draw(G,pos=nx.fruchterman_reingold_layout(G), nodecolor='y',edge_color='b',labels='label')
plt.show()

#Play around with the nodes turned into a dataframe
df = pd.DataFrame(G.node)
df.ix['value'].unique()

#Quick checks
G.is_directed()
G.is_multigraph()
# Out:
# True

# %%
#g = nx.DiGraph((x, y, {'weight': v}) for (x, y), v in Counter(G.edges()).items())
#edge_weights = g.edges(data=True)

nx.set_edge_attributes(G,'weight',1)
nx.set_node_attributes(G,'centrality',degree_centrality(G))

# %%
G.nodes(data=True)
# Out:
# [(0,
#   {'centrality': 0.10526315789473684,
#    'id': 0,
#    'label': u'BrighamYoung',
#    'value': 7}),
#  (1,
#   {'centrality': 0.10526315789473684,
#    'id': 1,
#    'label': u'FloridaState',
#    'value': 0}),
#  (2,
#   {'centrality': 0.10526315789473684, 'id': 2, 'label': u'Iowa', 'value': 2}),
#  (3,
#   {'centrality': 0.11403508771929824,
#    'id': 3,
#    'label': u'KansasState',
#    'value': 3}),
#  (4,
#   {'centrality': 0.09649122807017543,
#    'id': 4,
#    'label': u'NewMexico',
#    'value': 7}),
#  (5,
#   {'centrality': 0.10526315789473684,
#    'id': 5,
#    'label': u'TexasTech',
#    'value': 3}),
#  (6,
#   {'centrality': 0.10526315789473684,
#    'id': 6,
#    'label': u'PennState',
#    'value': 2}),
#  (7,
#   {'centrality': 0.10526315789473684,
#    'id': 7,
#    'label': u'SouthernCalifornia',
#    'value': 8}),
#  (8,
#   {'centrality': 0.09649122807017543,
#    'id': 8,
#    'label': u'ArizonaState',
#    'value': 8}),
#  (9,
#   {'centrality': 0.09649122807017543,
#    'id': 9,
#    'label': u'SanDiegoState',
#    'value': 7}),
#  (10,
#   {'centrality': 0.08771929824561403,
#    'id': 10,
#    'label': u'Baylor',
#    'value': 3}),
#  (11,
#   {'centrality': 0.08771929824561403,
#    'id': 11,
#    'label': u'NorthTexas',
#    'value': 10}),
#  (12,
#   {'centrality': 0.08771929824561403,
#    'id': 12,
#    'label': u'NorthernIllinois',
#    'value': 6}),
#  (13,
#   {'centrality': 0.09649122807017543,
#    'id': 13,
#    'label': u'Northwestern',
#    'value': 2}),
#  (14,
#   {'centrality': 0.09649122807017543,
#    'id': 14,
#    'label': u'WesternMichigan',
#    'value': 6}),
#  (15,
#   {'centrality': 0.10526315789473684,
#    'id': 15,
#    'label': u'Wisconsin',
#    'value': 2}),
#  (16,
#   {'centrality': 0.09649122807017543,
#    'id': 16,
#    'label': u'Wyoming',
#    'value': 7}),
#  (17,
#   {'centrality': 0.10526315789473684,
#    'id': 17,
#    'label': u'Auburn',
#    'value': 9}),
#  (18,
#   {'centrality': 0.09649122807017543,
#    'id': 18,
#    'label': u'Akron',
#    'value': 6}),
#  (19,
#   {'centrality': 0.09649122807017543,
#    'id': 19,
#    'label': u'VirginiaTech',
#    'value': 1}),
#  (20,
#   {'centrality': 0.09649122807017543,
#    'id': 20,
#    'label': u'Alabama',
#    'value': 9}),
#  (21,
#   {'centrality': 0.09649122807017543, 'id': 21, 'label': u'UCLA', 'value': 8}),
#  (22,
#   {'centrality': 0.09649122807017543,
#    'id': 22,
#    'label': u'Arizona',
#    'value': 8}),
#  (23,
#   {'centrality': 0.09649122807017543, 'id': 23, 'label': u'Utah', 'value': 7}),
#  (24,
#   {'centrality': 0.08771929824561403,
#    'id': 24,
#    'label': u'ArkansasState',
#    'value': 10}),
#  (25,
#   {'centrality': 0.09649122807017543,
#    'id': 25,
#    'label': u'NorthCarolinaState',
#    'value': 0}),
#  (26,
#   {'centrality': 0.08771929824561403,
#    'id': 26,
#    'label': u'BallState',
#    'value': 6}),
#  (27,
#   {'centrality': 0.10526315789473684,
#    'id': 27,
#    'label': u'Florida',
#    'value': 9}),
#  (28,
#   {'centrality': 0.07894736842105263,
#    'id': 28,
#    'label': u'BoiseState',
#    'value': 11}),
#  (29,
#   {'centrality': 0.09649122807017543,
#    'id': 29,
#    'label': u'BostonCollege',
#    'value': 1}),
#  (30,
#   {'centrality': 0.09649122807017543,
#    'id': 30,
#    'label': u'WestVirginia',
#    'value': 1}),
#  (31,
#   {'centrality': 0.09649122807017543,
#    'id': 31,
#    'label': u'BowlingGreenState',
#    'value': 6}),
#  (32,
#   {'centrality': 0.09649122807017543,
#    'id': 32,
#    'label': u'Michigan',
#    'value': 2}),
#  (33,
#   {'centrality': 0.08771929824561403,
#    'id': 33,
#    'label': u'Virginia',
#    'value': 0}),
#  (34,
#   {'centrality': 0.09649122807017543,
#    'id': 34,
#    'label': u'Buffalo',
#    'value': 6}),
#  (35,
#   {'centrality': 0.09649122807017543,
#    'id': 35,
#    'label': u'Syracuse',
#    'value': 1}),
#  (36,
#   {'centrality': 0.07017543859649122,
#    'id': 36,
#    'label': u'CentralFlorida',
#    'value': 5}),
#  (37,
#   {'centrality': 0.09649122807017543,
#    'id': 37,
#    'label': u'GeorgiaTech',
#    'value': 0}),
#  (38,
#   {'centrality': 0.09649122807017543,
#    'id': 38,
#    'label': u'CentralMichigan',
#    'value': 6}),
#  (39,
#   {'centrality': 0.09649122807017543,
#    'id': 39,
#    'label': u'Purdue',
#    'value': 2}),
#  (40,
#   {'centrality': 0.09649122807017543,
#    'id': 40,
#    'label': u'Colorado',
#    'value': 3}),
#  (41,
#   {'centrality': 0.08771929824561403,
#    'id': 41,
#    'label': u'ColoradoState',
#    'value': 7}),
#  (42,
#   {'centrality': 0.06140350877192982,
#    'id': 42,
#    'label': u'Connecticut',
#    'value': 5}),
#  (43,
#   {'centrality': 0.09649122807017543,
#    'id': 43,
#    'label': u'EasternMichigan',
#    'value': 6}),
#  (44,
#   {'centrality': 0.09649122807017543,
#    'id': 44,
#    'label': u'EastCarolina',
#    'value': 4}),
#  (45,
#   {'centrality': 0.09649122807017543, 'id': 45, 'label': u'Duke', 'value': 0}),
#  (46,
#   {'centrality': 0.09649122807017543,
#    'id': 46,
#    'label': u'FresnoState',
#    'value': 11}),
#  (47,
#   {'centrality': 0.09649122807017543,
#    'id': 47,
#    'label': u'OhioState',
#    'value': 2}),
#  (48,
#   {'centrality': 0.09649122807017543,
#    'id': 48,
#    'label': u'Houston',
#    'value': 4}),
#  (49,
#   {'centrality': 0.09649122807017543,
#    'id': 49,
#    'label': u'Rice',
#    'value': 11}),
#  (50,
#   {'centrality': 0.07894736842105263,
#    'id': 50,
#    'label': u'Idaho',
#    'value': 10}),
#  (51,
#   {'centrality': 0.09649122807017543,
#    'id': 51,
#    'label': u'Washington',
#    'value': 8}),
#  (52,
#   {'centrality': 0.08771929824561403,
#    'id': 52,
#    'label': u'Kansas',
#    'value': 3}),
#  (53,
#   {'centrality': 0.10526315789473684,
#    'id': 53,
#    'label': u'SouthernMethodist',
#    'value': 11}),
#  (54,
#   {'centrality': 0.08771929824561403, 'id': 54, 'label': u'Kent', 'value': 6}),
#  (55,
#   {'centrality': 0.09649122807017543,
#    'id': 55,
#    'label': u'Pittsburgh',
#    'value': 1}),
#  (56,
#   {'centrality': 0.08771929824561403,
#    'id': 56,
#    'label': u'Kentucky',
#    'value': 9}),
#  (57,
#   {'centrality': 0.08771929824561403,
#    'id': 57,
#    'label': u'Louisville',
#    'value': 4}),
#  (58,
#   {'centrality': 0.08771929824561403,
#    'id': 58,
#    'label': u'LouisianaTech',
#    'value': 11}),
#  (59,
#   {'centrality': 0.07017543859649122,
#    'id': 59,
#    'label': u'LouisianaMonroe',
#    'value': 10}),
#  (60,
#   {'centrality': 0.09649122807017543,
#    'id': 60,
#    'label': u'Minnesota',
#    'value': 2}),
#  (61,
#   {'centrality': 0.09649122807017543,
#    'id': 61,
#    'label': u'MiamiOhio',
#    'value': 6}),
#  (62,
#   {'centrality': 0.09649122807017543,
#    'id': 62,
#    'label': u'Vanderbilt',
#    'value': 9}),
#  (63,
#   {'centrality': 0.07894736842105263,
#    'id': 63,
#    'label': u'MiddleTennesseeState',
#    'value': 10}),
#  (64,
#   {'centrality': 0.09649122807017543,
#    'id': 64,
#    'label': u'Illinois',
#    'value': 2}),
#  (65,
#   {'centrality': 0.09649122807017543,
#    'id': 65,
#    'label': u'MississippiState',
#    'value': 9}),
#  (66,
#   {'centrality': 0.09649122807017543,
#    'id': 66,
#    'label': u'Memphis',
#    'value': 4}),
#  (67,
#   {'centrality': 0.10526315789473684,
#    'id': 67,
#    'label': u'Nevada',
#    'value': 11}),
#  (68,
#   {'centrality': 0.09649122807017543,
#    'id': 68,
#    'label': u'Oregon',
#    'value': 8}),
#  (69,
#   {'centrality': 0.09649122807017543,
#    'id': 69,
#    'label': u'NewMexicoState',
#    'value': 10}),
#  (70,
#   {'centrality': 0.09649122807017543,
#    'id': 70,
#    'label': u'SouthCarolina',
#    'value': 9}),
#  (71,
#   {'centrality': 0.08771929824561403, 'id': 71, 'label': u'Ohio', 'value': 6}),
#  (72,
#   {'centrality': 0.09649122807017543,
#    'id': 72,
#    'label': u'IowaState',
#    'value': 3}),
#  (73,
#   {'centrality': 0.09649122807017543,
#    'id': 73,
#    'label': u'SanJoseState',
#    'value': 11}),
#  (74,
#   {'centrality': 0.09649122807017543,
#    'id': 74,
#    'label': u'Nebraska',
#    'value': 3}),
#  (75,
#   {'centrality': 0.08771929824561403,
#    'id': 75,
#    'label': u'SouthernMississippi',
#    'value': 4}),
#  (76,
#   {'centrality': 0.09649122807017543,
#    'id': 76,
#    'label': u'Tennessee',
#    'value': 9}),
#  (77,
#   {'centrality': 0.09649122807017543,
#    'id': 77,
#    'label': u'Stanford',
#    'value': 8}),
#  (78,
#   {'centrality': 0.09649122807017543,
#    'id': 78,
#    'label': u'WashingtonState',
#    'value': 8}),
#  (79,
#   {'centrality': 0.09649122807017543,
#    'id': 79,
#    'label': u'Temple',
#    'value': 1}),
#  (80,
#   {'centrality': 0.09649122807017543, 'id': 80, 'label': u'Navy', 'value': 5}),
#  (81,
#   {'centrality': 0.09649122807017543,
#    'id': 81,
#    'label': u'TexasA&M',
#    'value': 3}),
#  (82,
#   {'centrality': 0.09649122807017543,
#    'id': 82,
#    'label': u'NotreDame',
#    'value': 5}),
#  (83,
#   {'centrality': 0.09649122807017543,
#    'id': 83,
#    'label': u'TexasElPaso',
#    'value': 11}),
#  (84,
#   {'centrality': 0.10526315789473684,
#    'id': 84,
#    'label': u'Oklahoma',
#    'value': 3}),
#  (85,
#   {'centrality': 0.07894736842105263,
#    'id': 85,
#    'label': u'Toledo',
#    'value': 6}),
#  (86,
#   {'centrality': 0.09649122807017543,
#    'id': 86,
#    'label': u'Tulane',
#    'value': 4}),
#  (87,
#   {'centrality': 0.09649122807017543,
#    'id': 87,
#    'label': u'Mississippi',
#    'value': 9}),
#  (88,
#   {'centrality': 0.10526315789473684,
#    'id': 88,
#    'label': u'Tulsa',
#    'value': 11}),
#  (89,
#   {'centrality': 0.09649122807017543,
#    'id': 89,
#    'label': u'NorthCarolina',
#    'value': 0}),
#  (90,
#   {'centrality': 0.07894736842105263,
#    'id': 90,
#    'label': u'UtahState',
#    'value': 5}),
#  (91,
#   {'centrality': 0.09649122807017543, 'id': 91, 'label': u'Army', 'value': 4}),
#  (92,
#   {'centrality': 0.09649122807017543,
#    'id': 92,
#    'label': u'Cincinnati',
#    'value': 4}),
#  (93,
#   {'centrality': 0.08771929824561403,
#    'id': 93,
#    'label': u'AirForce',
#    'value': 7}),
#  (94,
#   {'centrality': 0.08771929824561403,
#    'id': 94,
#    'label': u'Rutgers',
#    'value': 1}),
#  (95,
#   {'centrality': 0.08771929824561403,
#    'id': 95,
#    'label': u'Georgia',
#    'value': 9}),
#  (96,
#   {'centrality': 0.08771929824561403,
#    'id': 96,
#    'label': u'LouisianaState',
#    'value': 9}),
#  (97,
#   {'centrality': 0.07017543859649122,
#    'id': 97,
#    'label': u'LouisianaLafayette',
#    'value': 10}),
#  (98,
#   {'centrality': 0.09649122807017543,
#    'id': 98,
#    'label': u'Texas',
#    'value': 3}),
#  (99,
#   {'centrality': 0.09649122807017543,
#    'id': 99,
#    'label': u'Marshall',
#    'value': 6}),
#  (100,
#   {'centrality': 0.09649122807017543,
#    'id': 100,
#    'label': u'MichiganState',
#    'value': 2}),
#  (101,
#   {'centrality': 0.08771929824561403,
#    'id': 101,
#    'label': u'MiamiFlorida',
#    'value': 1}),
#  (102,
#   {'centrality': 0.08771929824561403,
#    'id': 102,
#    'label': u'Missouri',
#    'value': 3}),
#  (103,
#   {'centrality': 0.08771929824561403,
#    'id': 103,
#    'label': u'Clemson',
#    'value': 0}),
#  (104,
#   {'centrality': 0.10526315789473684,
#    'id': 104,
#    'label': u'NevadaLasVegas',
#    'value': 7}),
#  (105,
#   {'centrality': 0.08771929824561403,
#    'id': 105,
#    'label': u'WakeForest',
#    'value': 0}),
#  (106,
#   {'centrality': 0.09649122807017543,
#    'id': 106,
#    'label': u'Indiana',
#    'value': 2}),
#  (107,
#   {'centrality': 0.08771929824561403,
#    'id': 107,
#    'label': u'OklahomaState',
#    'value': 3}),
#  (108,
#   {'centrality': 0.08771929824561403,
#    'id': 108,
#    'label': u'OregonState',
#    'value': 8}),
#  (109,
#   {'centrality': 0.09649122807017543,
#    'id': 109,
#    'label': u'Maryland',
#    'value': 0}),
#  (110,
#   {'centrality': 0.09649122807017543,
#    'id': 110,
#    'label': u'TexasChristian',
#    'value': 4}),
#  (111,
#   {'centrality': 0.09649122807017543,
#    'id': 111,
#    'label': u'California',
#    'value': 8}),
#  (112,
#   {'centrality': 0.08771929824561403,
#    'id': 112,
#    'label': u'AlabamaBirmingham',
#    'value': 4}),
#  (113,
#   {'centrality': 0.08771929824561403,
#    'id': 113,
#    'label': u'Arkansas',
#    'value': 9}),
#  (114,
#   {'centrality': 0.09649122807017543,
#    'id': 114,
#    'label': u'Hawaii',
#    'value': 11})]
