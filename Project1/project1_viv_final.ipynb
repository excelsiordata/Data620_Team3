# %%
# For this project, we are using networkx 1.9.1 since GML is failed to parse in the new version.
# For our project, we choose the network of games of the American College Football
# during the Fall 2000.
from networkx import *
import matplotlib.pyplot as plt
from collections import defaultdict
# %matplotlib inline
import scipy.stats as stats
import math


import numpy as np
import pandas as pd
import community
import networkx as nx
url="http://www-personal.umich.edu/~mejn/netdata/football.zip"

import urllib
import io
import zipfile

football = urllib.urlopen(url)  # open URL
f=io.BytesIO(football.read()) # read into BytesIO "file"
football.close()

zf = zipfile.ZipFile(f) # zipfile object
txt=zf.read('football.txt').decode() # read info file
gml=zf.read('football.gml').decode() # read gml data
# throw away bogus first line with # from mejn files
gml=gml.split('\n')[1:]
G=parse_gml(gml) # parse gml data
g=nx.Graph(G)

# %%
nx.draw_spring(g,node_size=0,edge_color='b', label=True, alpha=.2, font_size=10)
plt.show()
g.is_multigraph()
# After we are graph this dataset, it becomes a huge"mess".
# Out:
# False

# %%
# The nodes are teams and the edges are the games between the teams. 
# As we are doing ‘nx.info()’, we found that there were 115 teams, 613 games in total
# and the average number of game is 10.7.
# Each node was assigned the ID which is from 0 to 114, and a conference ID which is from 0 to 11.
# The Conference ID is based on which conference the colleges belonged to.
print nx.info(g)
G.is_directed()
# This network is also not a directed network, which means from the network, we may not be able 
# to figure who wined or lost.
# Out:
# Name: ()
# Type: Graph
# Number of nodes: 115
# Number of edges: 613
# Average degree:  10.6609
# False

# %%
#So, We decide to give each conference group a color and try to graph again.
##0 = Atlantic Coast
##1 = Big East
##2 = Big Ten
##3 = BigTwelve
##4 = Conference USA
##5 = Independents
##6 = Mid-American
##7 = MountainWest
##8 = PacificTen
##9 = Southeastern
##10 = SunBelt
##11 = WesternAthletic.


ACC=[]
BigEast=[]
Big10=[]
Big12=[]
ConferenceUSA=[]
Independants=[]
MidAmerican=[]
MountainWest=[]
PacTen=[]
SEC=[]
SunBelt=[]
WesternAthletic= []

node_color = []

for i,j in g.nodes_iter(data = True):
    if j['value'] == 0:
        ACC.append(i)
        node_color.append('red')
    elif j['value'] == 1:
        BigEast.append(i)
        node_color.append('yellow')
    elif j['value']== 2:
        Big10.append(i)
        node_color.append('black')
    elif j['value']== 3:
        Big12.append(i)
        node_color.append('purple')
    elif j['value']== 4:
        ConferenceUSA.append(i)
        node_color.append('green')
    elif j['value']== 5:
        Independants.append(i)
        node_color.append('grey')
    elif j['value']== 6:
        MidAmerican.append(i)
        node_color.append('orange')
    elif j['value']== 7:
        MountainWest.append(i)
        node_color.append('blue')
    elif j['value']== 8:
        PacTen.append(i)
        node_color.append('white')
    elif j['value']== 9:
        SEC.append(i)
        node_color.append('pink')
    elif j['value']== 10:
        SunBelt.append(i)
        node_color.append('silver')
    else:
        WesternAthletic.append(i)
        node_color.append('crimson')
nx.draw_spring(g,node_size=300,edge_color='black', with_labels = True, alpha=.8, font_size=10, node_color = node_color )
plt.show()

# %%
# OK! Now, it becomes a little bit better. Now we are gonna break teams into their own conference group.

# For Atlantic Coast Conference
g_ACC= g.subgraph(ACC)

nx.draw(g_ACC, with_labels=True)
plt.show()
len(g_ACC) # There are 9 teams in this conference group.
# Out:
# 9

# %%
deg=nx.degree(g_ACC)
# This function returns a sorted degree list- can help us to spot the Teams which played the mose of games
def sorted_map(map):
    ms = sorted(map.iteritems(), key=lambda(k,v): (-v,k))
    return ms
ds = sorted_map(deg)
ds # From the result, we can see that all the teams in ACC compete with each other.
# However, for big conference groups, they may not be able to compete with each other such as 
#Big Ten, they have 11 teams but they only play 8 games.
# Out:
# [(u'Clemson', 8),
#  (u'Duke', 8),
#  (u'FloridaState', 8),
#  (u'GeorgiaTech', 8),
#  (u'Maryland', 8),
#  (u'NorthCarolina', 8),
#  (u'NorthCarolinaState', 8),
#  (u'Virginia', 8),
#  (u'WakeForest', 8)]

# %%
# For Big East conference group.
g_BigEast= g.subgraph(BigEast)

nx.draw(g_BigEast, with_labels=True)
plt.show()
len(g_BigEast) # There are 8 teams in this conference group.
# Out:
# 8

# %%
deg=nx.degree(g_BigEast)
ds=sorted_map(deg)
ds
# Out:
# [(u'BostonCollege', 7),
#  (u'MiamiFlorida', 7),
#  (u'Pittsburgh', 7),
#  (u'Rutgers', 7),
#  (u'Syracuse', 7),
#  (u'Temple', 7),
#  (u'VirginiaTech', 7),
#  (u'WestVirginia', 7)]

# %%
# For Big Ten

g_Big10= g.subgraph(Big10)

nx.draw(g_Big10, with_labels=True)
plt.show()
len(g_Big10) # There are 11 teams in this conference group.
# Out:
# 11

# %%
deg=nx.degree(g_Big10)
ds = sorted_map(deg)
ds
# Out:
# [(u'Illinois', 8),
#  (u'Indiana', 8),
#  (u'Iowa', 8),
#  (u'Michigan', 8),
#  (u'MichiganState', 8),
#  (u'Minnesota', 8),
#  (u'Northwestern', 8),
#  (u'OhioState', 8),
#  (u'PennState', 8),
#  (u'Purdue', 8),
#  (u'Wisconsin', 8)]

# %%
g_Big12= g.subgraph(Big12)

nx.draw(g_Big12, with_labels=True)
plt.show()
len(g_Big12) # There are 12 teams in this conference group.
# Out:
# 12

# %%
deg=nx.degree(g_Big12)
ds = sorted_map(deg)
ds
# Out:
# [(u'Baylor', 8),
#  (u'Colorado', 8),
#  (u'IowaState', 8),
#  (u'Kansas', 8),
#  (u'KansasState', 8),
#  (u'Missouri', 8),
#  (u'Nebraska', 8),
#  (u'Oklahoma', 8),
#  (u'OklahomaState', 8),
#  (u'Texas', 8),
#  (u'TexasA&M', 8),
#  (u'TexasTech', 8)]

# %%
g_ConferenceUSA= g.subgraph(ConferenceUSA)

nx.draw(g_ConferenceUSA, with_labels=True)
plt.show()
len(g_ConferenceUSA) # There are 10 teams in this conference group.
# Out:
# 10

# %%
deg=nx.degree(g_ConferenceUSA)
ds = sorted_map(deg)
ds
# Out:
# [(u'Army', 7),
#  (u'Cincinnati', 7),
#  (u'EastCarolina', 7),
#  (u'Houston', 7),
#  (u'Louisville', 7),
#  (u'Memphis', 7),
#  (u'SouthernMississippi', 7),
#  (u'Tulane', 7),
#  (u'AlabamaBirmingham', 6),
#  (u'TexasChristian', 0)]

# %%
g_Independants= g.subgraph(Independants)

nx.draw(g_Independants, with_labels=True)
plt.show()
len(g_Independants) # There are 5 teams in this conference group.
# Out:
# 5

# %%
deg=nx.degree(g_Independants)
ds = sorted_map(deg)
ds
# Out:
# [(u'Navy', 1),
#  (u'NotreDame', 1),
#  (u'CentralFlorida', 0),
#  (u'Connecticut', 0),
#  (u'UtahState', 0)]

# %%
g_MidAmerican= g.subgraph(MidAmerican)

nx.draw(g_MidAmerican, with_labels=True)
plt.show()
len(g_MidAmerican) # There are 13 teams in this conference group.
# Out:
# 13

# %%
deg=nx.degree(g_MidAmerican)
ds = sorted_map(deg)
ds
# Out:
# [(u'Akron', 8),
#  (u'BowlingGreenState', 8),
#  (u'Buffalo', 8),
#  (u'CentralMichigan', 8),
#  (u'Kent', 8),
#  (u'Marshall', 8),
#  (u'MiamiOhio', 8),
#  (u'Ohio', 8),
#  (u'WesternMichigan', 8),
#  (u'BallState', 7),
#  (u'EasternMichigan', 7),
#  (u'NorthernIllinois', 7),
#  (u'Toledo', 7)]

# %%
g_MountainWest= g.subgraph(MountainWest)

nx.draw(g_MountainWest, with_labels=True)
plt.show()
len(g_MountainWest) # There are 8 teams in this conference group.
# Out:
# 8

# %%
deg=nx.degree(g_MountainWest)
ds = sorted_map(deg)
ds
# Out:
# [(u'AirForce', 7),
#  (u'BrighamYoung', 7),
#  (u'ColoradoState', 7),
#  (u'NevadaLasVegas', 7),
#  (u'NewMexico', 7),
#  (u'SanDiegoState', 7),
#  (u'Utah', 7),
#  (u'Wyoming', 7)]

# %%
g_PacTen= g.subgraph(PacTen)

nx.draw(g_PacTen, with_labels=True)
plt.show()
len(g_PacTen) # There are 10 teams in this conference group.
# Out:
# 10

# %%
deg=nx.degree(g_PacTen)
ds = sorted_map(deg)
ds
# Out:
# [(u'Arizona', 8),
#  (u'ArizonaState', 8),
#  (u'California', 8),
#  (u'Oregon', 8),
#  (u'OregonState', 8),
#  (u'SouthernCalifornia', 8),
#  (u'Stanford', 8),
#  (u'UCLA', 8),
#  (u'Washington', 8),
#  (u'WashingtonState', 8)]

# %%
g_SEC= g.subgraph(SEC)

nx.draw(g_SEC, with_labels=True)
plt.show()
len(g_SEC) # There are 12 teams in this conference group.
# Out:
# 12

# %%
deg=nx.degree(g_SEC)
ds = sorted_map(deg)
ds
# Out:
# [(u'Alabama', 8),
#  (u'Arkansas', 8),
#  (u'Auburn', 8),
#  (u'Florida', 8),
#  (u'Georgia', 8),
#  (u'Kentucky', 8),
#  (u'LouisianaState', 8),
#  (u'Mississippi', 8),
#  (u'MississippiState', 8),
#  (u'SouthCarolina', 8),
#  (u'Tennessee', 8),
#  (u'Vanderbilt', 8)]

# %%
g_SunBelt= g.subgraph(SunBelt)

nx.draw(g_SunBelt, with_labels=True)
plt.show()
len(g_SunBelt) # There are 7 teams in this conference group.
# Out:
# 7

# %%
deg=nx.degree(g_SunBelt)
ds = sorted_map(deg)
ds
# Out:
# [(u'NorthTexas', 4),
#  (u'ArkansasState', 3),
#  (u'Idaho', 3),
#  (u'LouisianaLafayette', 3),
#  (u'NewMexicoState', 3),
#  (u'LouisianaMonroe', 2),
#  (u'MiddleTennesseeState', 2)]

# %%
g_WesternAthletic= g.subgraph(WesternAthletic)

nx.draw(g_WesternAthletic, with_labels=True)
plt.show()
len(g_WesternAthletic) # There are 10 teams in this conference group.
# Out:
# 10

# %%
deg=nx.degree(g_WesternAthletic)
ds = sorted_map(deg)
ds
# Out:
# [(u'Hawaii', 8),
#  (u'Tulsa', 8),
#  (u'FresnoState', 7),
#  (u'Nevada', 7),
#  (u'Rice', 7),
#  (u'SanJoseState', 7),
#  (u'SouthernMethodist', 7),
#  (u'TexasElPaso', 7),
#  (u'LouisianaTech', 2),
#  (u'BoiseState', 0)]

# %%
#Since NCAA imposes rules restricting the number of games each team can play, either 11 or 12, the teams in this network
#all have similar degree. As the graphs, we can have the same result. 
def trim_nodes(G,d):
    Gt=G.copy()
    dn=nx.degree(Gt)
    for n in Gt.nodes():
        if dn[n]<=d:
            Gt.remove_node(n)
    return Gt

# %%
# There are 12 teams play 12 games
Gt = trim_nodes(g,11)
plt.axis('off')

nx.draw(Gt, node_size=200, node_color='r', edge_color='b', alpha=0.8,with_labels = True)
plt.show()
len(Gt)
# Out:
# 12

# %%
# There are 66 teams play 11 games.
Gt = trim_nodes(g,10)
plt.axis('off')

nx.draw(Gt, node_size=200, node_color='r', edge_color='b', alpha=0.8,with_labels = True)
plt.show()
len(Gt)
# Out:
# 78

# %%
deg=nx.degree(G)
min(deg.values())
# Out:
# 7

# %%
max(deg.values())
# Out:
# 12

# %%
# Top 15 teams in the list
ds = sorted_map(deg)
ds[:10]
# Out:
# [(u'BrighamYoung', 12),
#  (u'FloridaState', 12),
#  (u'Iowa', 12),
#  (u'KansasState', 12),
#  (u'Nevada', 12),
#  (u'NevadaLasVegas', 12),
#  (u'PennState', 12),
#  (u'SouthernCalifornia', 12),
#  (u'SouthernMethodist', 12),
#  (u'TexasTech', 12)]

# %%
h = plt.hist(deg.values())
plt.show(h)

# This histogram is highly skewd left.

# %%
nx.set_edge_attributes(G,'weight',1)
nx.set_node_attributes(G,'centrality',degree_centrality(G))
nG = nx.Graph()
nG.add_nodes_from(G.nodes(data=True))

# %%
G.edges(data=True)
# Out:
# [(u'Mississippi', u'Georgia', {'weight': 1}),
#  (u'Mississippi', u'MississippiState', {'weight': 1}),
#  (u'Mississippi', u'Tulane', {'weight': 1}),
#  (u'Mississippi', u'Vanderbilt', {'weight': 1}),
#  (u'Mississippi', u'Kentucky', {'weight': 1}),
#  (u'Mississippi', u'Auburn', {'weight': 1}),
#  (u'Mississippi', u'Arkansas', {'weight': 1}),
#  (u'Mississippi', u'LouisianaState', {'weight': 1}),
#  (u'Mississippi', u'NevadaLasVegas', {'weight': 1}),
#  (u'Mississippi', u'Alabama', {'weight': 1}),
#  (u'Mississippi', u'ArkansasState', {'weight': 1}),
#  (u'OregonState', u'SouthernCalifornia', {'weight': 1}),
#  (u'OregonState', u'WashingtonState', {'weight': 1}),
#  (u'OregonState', u'Arizona', {'weight': 1}),
#  (u'OregonState', u'Stanford', {'weight': 1}),
#  (u'OregonState', u'SanDiegoState', {'weight': 1}),
#  (u'OregonState', u'Washington', {'weight': 1}),
#  (u'OregonState', u'UCLA', {'weight': 1}),
#  (u'OregonState', u'Oregon', {'weight': 1}),
#  (u'OregonState', u'California', {'weight': 1}),
#  (u'OregonState', u'NewMexico', {'weight': 1}),
#  (u'NotreDame', u'SouthernCalifornia', {'weight': 1}),
#  (u'NotreDame', u'BostonCollege', {'weight': 1}),
#  (u'NotreDame', u'AirForce', {'weight': 1}),
#  (u'NotreDame', u'Stanford', {'weight': 1}),
#  (u'NotreDame', u'Purdue', {'weight': 1}),
#  (u'NotreDame', u'TexasA&M', {'weight': 1}),
#  (u'NotreDame', u'Nebraska', {'weight': 1}),
#  (u'NotreDame', u'WestVirginia', {'weight': 1}),
#  (u'NotreDame', u'Navy', {'weight': 1}),
#  (u'NotreDame', u'MichiganState', {'weight': 1}),
#  (u'NotreDame', u'Rutgers', {'weight': 1}),
#  (u'Wyoming', u'CentralMichigan', {'weight': 1}),
#  (u'Wyoming', u'AirForce', {'weight': 1}),
#  (u'Wyoming', u'TexasA&M', {'weight': 1}),
#  (u'Wyoming', u'SanDiegoState', {'weight': 1}),
#  (u'Wyoming', u'BrighamYoung', {'weight': 1}),
#  (u'Wyoming', u'Utah', {'weight': 1}),
#  (u'Wyoming', u'Auburn', {'weight': 1}),
#  (u'Wyoming', u'ColoradoState', {'weight': 1}),
#  (u'Wyoming', u'NevadaLasVegas', {'weight': 1}),
#  (u'Wyoming', u'NewMexico', {'weight': 1}),
#  (u'Wyoming', u'Nevada', {'weight': 1}),
#  (u'Minnesota', u'OhioState', {'weight': 1}),
#  (u'Minnesota', u'PennState', {'weight': 1}),
#  (u'Minnesota', u'LouisianaMonroe', {'weight': 1}),
#  (u'Minnesota', u'Wisconsin', {'weight': 1}),
#  (u'Minnesota', u'Northwestern', {'weight': 1}),
#  (u'Minnesota', u'Purdue', {'weight': 1}),
#  (u'Minnesota', u'Illinois', {'weight': 1}),
#  (u'Minnesota', u'Baylor', {'weight': 1}),
#  (u'Minnesota', u'Indiana', {'weight': 1}),
#  (u'Minnesota', u'Ohio', {'weight': 1}),
#  (u'Minnesota', u'Iowa', {'weight': 1}),
#  (u'Illinois', u'PennState', {'weight': 1}),
#  (u'Illinois', u'Iowa', {'weight': 1}),
#  (u'Illinois', u'OhioState', {'weight': 1}),
#  (u'Illinois', u'SanDiegoState', {'weight': 1}),
#  (u'Illinois', u'Michigan', {'weight': 1}),
#  (u'Illinois', u'California', {'weight': 1}),
#  (u'Illinois', u'MiddleTennesseeState', {'weight': 1}),
#  (u'Illinois', u'MichiganState', {'weight': 1}),
#  (u'Illinois', u'Indiana', {'weight': 1}),
#  (u'Illinois', u'Northwestern', {'weight': 1}),
#  (u'Kent', u'CentralMichigan', {'weight': 1}),
#  (u'Kent', u'Purdue', {'weight': 1}),
#  (u'Kent', u'Pittsburgh', {'weight': 1}),
#  (u'Kent', u'Marshall', {'weight': 1}),
#  (u'Kent', u'BowlingGreenState', {'weight': 1}),
#  (u'Kent', u'MiamiOhio', {'weight': 1}),
#  (u'Kent', u'WesternMichigan', {'weight': 1}),
#  (u'Kent', u'Akron', {'weight': 1}),
#  (u'Kent', u'Ohio', {'weight': 1}),
#  (u'Kent', u'Buffalo', {'weight': 1}),
#  (u'Toledo', u'PennState', {'weight': 1}),
#  (u'Toledo', u'CentralMichigan', {'weight': 1}),
#  (u'Toledo', u'Marshall', {'weight': 1}),
#  (u'Toledo', u'BallState', {'weight': 1}),
#  (u'Toledo', u'BowlingGreenState', {'weight': 1}),
#  (u'Toledo', u'EasternMichigan', {'weight': 1}),
#  (u'Toledo', u'NorthernIllinois', {'weight': 1}),
#  (u'Toledo', u'WesternMichigan', {'weight': 1}),
#  (u'Toledo', u'Navy', {'weight': 1}),
#  (u'Indiana', u'PennState', {'weight': 1}),
#  (u'Indiana', u'Wisconsin', {'weight': 1}),
#  (u'Indiana', u'Northwestern', {'weight': 1}),
#  (u'Indiana', u'Michigan', {'weight': 1}),
#  (u'Indiana', u'Purdue', {'weight': 1}),
#  (u'Indiana', u'Kentucky', {'weight': 1}),
#  (u'Indiana', u'Cincinnati', {'weight': 1}),
#  (u'Indiana', u'Iowa', {'weight': 1}),
#  (u'Indiana', u'NorthCarolinaState', {'weight': 1}),
#  (u'Clemson', u'Duke', {'weight': 1}),
#  (u'Clemson', u'WakeForest', {'weight': 1}),
#  (u'Clemson', u'FloridaState', {'weight': 1}),
#  (u'Clemson', u'NorthCarolina', {'weight': 1}),
#  (u'Clemson', u'Virginia', {'weight': 1}),
#  (u'Clemson', u'GeorgiaTech', {'weight': 1}),
#  (u'Clemson', u'SouthCarolina', {'weight': 1}),
#  (u'Clemson', u'Missouri', {'weight': 1}),
#  (u'Clemson', u'Maryland', {'weight': 1}),
#  (u'Clemson', u'NorthCarolinaState', {'weight': 1}),
#  (u'Texas', u'Houston', {'weight': 1}),
#  (u'Texas', u'Colorado', {'weight': 1}),
#  (u'Texas', u'Stanford', {'weight': 1}),
#  (u'Texas', u'Oklahoma', {'weight': 1}),
#  (u'Texas', u'Kansas', {'weight': 1}),
#  (u'Texas', u'LouisianaLafayette', {'weight': 1}),
#  (u'Texas', u'Baylor', {'weight': 1}),
#  (u'Texas', u'TexasA&M', {'weight': 1}),
#  (u'Texas', u'OklahomaState', {'weight': 1}),
#  (u'Texas', u'TexasTech', {'weight': 1}),
#  (u'Texas', u'Missouri', {'weight': 1}),
#  (u'BostonCollege', u'Army', {'weight': 1}),
#  (u'BostonCollege', u'Pittsburgh', {'weight': 1}),
#  (u'BostonCollege', u'Connecticut', {'weight': 1}),
#  (u'BostonCollege', u'Rutgers', {'weight': 1}),
#  (u'BostonCollege', u'WestVirginia', {'weight': 1}),
#  (u'BostonCollege', u'Navy', {'weight': 1}),
#  (u'BostonCollege', u'VirginiaTech', {'weight': 1}),
#  (u'BostonCollege', u'MiamiFlorida', {'weight': 1}),
#  (u'BostonCollege', u'Temple', {'weight': 1}),
#  (u'BostonCollege', u'Syracuse', {'weight': 1}),
#  (u'MississippiState', u'BrighamYoung', {'weight': 1}),
#  (u'MississippiState', u'Florida', {'weight': 1}),
#  (u'MississippiState', u'Kentucky', {'weight': 1}),
#  (u'MississippiState', u'Auburn', {'weight': 1}),
#  (u'MississippiState', u'MiddleTennesseeState', {'weight': 1}),
#  (u'MississippiState', u'Arkansas', {'weight': 1}),
#  (u'MississippiState', u'SouthCarolina', {'weight': 1}),
#  (u'MississippiState', u'Alabama', {'weight': 1}),
#  (u'MississippiState', u'Memphis', {'weight': 1}),
#  (u'MississippiState', u'LouisianaState', {'weight': 1}),
#  (u'Tulsa', u'NewMexicoState', {'weight': 1}),
#  (u'Tulsa', u'Nevada', {'weight': 1}),
#  (u'Tulsa', u'LouisianaTech', {'weight': 1}),
#  (u'Tulsa', u'NorthCarolina', {'weight': 1}),
#  (u'Tulsa', u'Hawaii', {'weight': 1}),
#  (u'Tulsa', u'SouthernMethodist', {'weight': 1}),
#  (u'Tulsa', u'TexasElPaso', {'weight': 1}),
#  (u'Tulsa', u'FresnoState', {'weight': 1}),
#  (u'Tulsa', u'OklahomaState', {'weight': 1}),
#  (u'Tulsa', u'TexasChristian', {'weight': 1}),
#  (u'Tulsa', u'Rice', {'weight': 1}),
#  (u'Tulsa', u'SanJoseState', {'weight': 1}),
#  (u'Kansas', u'AlabamaBirmingham', {'weight': 1}),
#  (u'Kansas', u'Colorado', {'weight': 1}),
#  (u'Kansas', u'Oklahoma', {'weight': 1}),
#  (u'Kansas', u'Missouri', {'weight': 1}),
#  (u'Kansas', u'SouthernMethodist', {'weight': 1}),
#  (u'Kansas', u'Nebraska', {'weight': 1}),
#  (u'Kansas', u'IowaState', {'weight': 1}),
#  (u'Kansas', u'TexasTech', {'weight': 1}),
#  (u'Kansas', u'KansasState', {'weight': 1}),
#  (u'SouthernMethodist', u'Houston', {'weight': 1}),
#  (u'SouthernMethodist', u'Nevada', {'weight': 1}),
#  (u'SouthernMethodist', u'Tulane', {'weight': 1}),
#  (u'SouthernMethodist', u'Hawaii', {'weight': 1}),
#  (u'SouthernMethodist', u'TexasElPaso', {'weight': 1}),
#  (u'SouthernMethodist', u'FresnoState', {'weight': 1}),
#  (u'SouthernMethodist', u'TexasChristian', {'weight': 1}),
#  (u'SouthernMethodist', u'Rice', {'weight': 1}),
#  (u'SouthernMethodist', u'SanJoseState', {'weight': 1}),
#  (u'SouthernMethodist', u'NorthCarolinaState', {'weight': 1}),
#  (u'Connecticut', u'BallState', {'weight': 1}),
#  (u'Connecticut', u'EasternMichigan', {'weight': 1}),
#  (u'Connecticut', u'Louisville', {'weight': 1}),
#  (u'Connecticut', u'MiddleTennesseeState', {'weight': 1}),
#  (u'Connecticut', u'Akron', {'weight': 1}),
#  (u'Connecticut', u'Buffalo', {'weight': 1}),
#  (u'Tulane', u'Houston', {'weight': 1}),
#  (u'Tulane', u'Cincinnati', {'weight': 1}),
#  (u'Tulane', u'Army', {'weight': 1}),
#  (u'Tulane', u'EastCarolina', {'weight': 1}),
#  (u'Tulane', u'LouisianaLafayette', {'weight': 1}),
#  (u'Tulane', u'Louisville', {'weight': 1}),
#  (u'Tulane', u'Navy', {'weight': 1}),
#  (u'Tulane', u'Memphis', {'weight': 1}),
#  (u'Tulane', u'SouthernMississippi', {'weight': 1}),
#  (u'Duke', u'Northwestern', {'weight': 1}),
#  (u'Duke', u'EastCarolina', {'weight': 1}),
#  (u'Duke', u'WakeForest', {'weight': 1}),
#  (u'Duke', u'FloridaState', {'weight': 1}),
#  (u'Duke', u'NorthCarolina', {'weight': 1}),
#  (u'Duke', u'Virginia', {'weight': 1}),
#  (u'Duke', u'GeorgiaTech', {'weight': 1}),
#  (u'Duke', u'Vanderbilt', {'weight': 1}),
#  (u'Duke', u'Maryland', {'weight': 1}),
#  (u'Duke', u'NorthCarolinaState', {'weight': 1}),
#  (u'Missouri', u'Colorado', {'weight': 1}),
#  (u'Missouri', u'Nebraska', {'weight': 1}),
#  (u'Missouri', u'Baylor', {'weight': 1}),
#  (u'Missouri', u'KansasState', {'weight': 1}),
#  (u'Missouri', u'MichiganState', {'weight': 1}),
#  (u'Missouri', u'OklahomaState', {'weight': 1}),
#  (u'Missouri', u'IowaState', {'weight': 1}),
#  (u'TexasChristian', u'Northwestern', {'weight': 1}),
#  (u'TexasChristian', u'Nevada', {'weight': 1}),
#  (u'TexasChristian', u'Hawaii', {'weight': 1}),
#  (u'TexasChristian', u'TexasElPaso', {'weight': 1}),
#  (u'TexasChristian', u'SanJoseState', {'weight': 1}),
#  (u'TexasChristian', u'FresnoState', {'weight': 1}),
#  (u'TexasChristian', u'Navy', {'weight': 1}),
#  (u'TexasChristian', u'Rice', {'weight': 1}),
#  (u'TexasChristian', u'ArkansasState', {'weight': 1}),
#  (u'LouisianaState', u'Houston', {'weight': 1}),
#  (u'LouisianaState', u'Florida', {'weight': 1}),
#  (u'LouisianaState', u'AlabamaBirmingham', {'weight': 1}),
#  (u'LouisianaState', u'Kentucky', {'weight': 1}),
#  (u'LouisianaState', u'Auburn', {'weight': 1}),
#  (u'LouisianaState', u'Tennessee', {'weight': 1}),
#  (u'LouisianaState', u'Arkansas', {'weight': 1}),
#  (u'LouisianaState', u'Alabama', {'weight': 1}),
#  (u'CentralFlorida', u'LouisianaMonroe', {'weight': 1}),
#  (u'CentralFlorida', u'LouisianaTech', {'weight': 1}),
#  (u'CentralFlorida', u'EasternMichigan', {'weight': 1}),
#  (u'CentralFlorida', u'GeorgiaTech', {'weight': 1}),
#  (u'CentralFlorida', u'NorthernIllinois', {'weight': 1}),
#  (u'CentralFlorida', u'Akron', {'weight': 1}),
#  (u'CentralFlorida', u'VirginiaTech', {'weight': 1}),
#  (u'CentralFlorida', u'Alabama', {'weight': 1}),
#  (u'Cincinnati', u'Houston', {'weight': 1}),
#  (u'Cincinnati', u'AlabamaBirmingham', {'weight': 1}),
#  (u'Cincinnati', u'Wisconsin', {'weight': 1}),
#  (u'Cincinnati', u'Army', {'weight': 1}),
#  (u'Cincinnati', u'MiamiOhio', {'weight': 1}),
#  (u'Cincinnati', u'Louisville', {'weight': 1}),
#  (u'Cincinnati', u'Memphis', {'weight': 1}),
#  (u'Cincinnati', u'SouthernMississippi', {'weight': 1}),
#  (u'Cincinnati', u'Syracuse', {'weight': 1}),
#  (u'Washington', u'WashingtonState', {'weight': 1}),
#  (u'Washington', u'Arizona', {'weight': 1}),
#  (u'Washington', u'Colorado', {'weight': 1}),
#  (u'Washington', u'ArizonaState', {'weight': 1}),
#  (u'Washington', u'Stanford', {'weight': 1}),
#  (u'Washington', u'UCLA', {'weight': 1}),
#  (u'Washington', u'Oregon', {'weight': 1}),
#  (u'Washington', u'California', {'weight': 1}),
#  (u'Washington', u'MiamiFlorida', {'weight': 1}),
#  (u'Washington', u'Idaho', {'weight': 1}),
#  (u'OklahomaState', u'Colorado', {'weight': 1}),
#  (u'OklahomaState', u'TexasA&M', {'weight': 1}),
#  (u'OklahomaState', u'Oklahoma', {'weight': 1}),
#  (u'OklahomaState', u'Baylor', {'weight': 1}),
#  (u'OklahomaState', u'IowaState', {'weight': 1}),
#  (u'OklahomaState', u'TexasTech', {'weight': 1}),
#  (u'OklahomaState', u'SouthernMississippi', {'weight': 1}),
#  (u'Marshall', u'NorthCarolina', {'weight': 1}),
#  (u'Marshall', u'MiamiOhio', {'weight': 1}),
#  (u'Marshall', u'BowlingGreenState', {'weight': 1}),
#  (u'Marshall', u'MichiganState', {'weight': 1}),
#  (u'Marshall', u'WesternMichigan', {'weight': 1}),
#  (u'Marshall', u'Akron', {'weight': 1}),
#  (u'Marshall', u'Ohio', {'weight': 1}),
#  (u'Marshall', u'Buffalo', {'weight': 1}),
#  (u'IowaState', u'Iowa', {'weight': 1}),
#  (u'IowaState', u'Colorado', {'weight': 1}),
#  (u'IowaState', u'TexasA&M', {'weight': 1}),
#  (u'IowaState', u'NevadaLasVegas', {'weight': 1}),
#  (u'IowaState', u'Baylor', {'weight': 1}),
#  (u'IowaState', u'KansasState', {'weight': 1}),
#  (u'IowaState', u'Ohio', {'weight': 1}),
#  (u'IowaState', u'Nebraska', {'weight': 1}),
#  (u'Army', u'Houston', {'weight': 1}),
#  (u'Army', u'AlabamaBirmingham', {'weight': 1}),
#  (u'Army', u'EastCarolina', {'weight': 1}),
#  (u'Army', u'NewMexicoState', {'weight': 1}),
#  (u'Army', u'Louisville', {'weight': 1}),
#  (u'Army', u'Navy', {'weight': 1}),
#  (u'Army', u'Memphis', {'weight': 1}),
#  (u'Army', u'AirForce', {'weight': 1}),
#  (u'LouisianaTech', u'PennState', {'weight': 1}),
#  (u'LouisianaTech', u'LouisianaMonroe', {'weight': 1}),
#  (u'LouisianaTech', u'Hawaii', {'weight': 1}),
#  (u'LouisianaTech', u'Auburn', {'weight': 1}),
#  (u'LouisianaTech', u'LouisianaLafayette', {'weight': 1}),
#  (u'LouisianaTech', u'MiddleTennesseeState', {'weight': 1}),
#  (u'LouisianaTech', u'KansasState', {'weight': 1}),
#  (u'LouisianaTech', u'MiamiFlorida', {'weight': 1}),
#  (u'AlabamaBirmingham', u'EastCarolina', {'weight': 1}),
#  (u'AlabamaBirmingham', u'MiddleTennesseeState', {'weight': 1}),
#  (u'AlabamaBirmingham', u'LouisianaLafayette', {'weight': 1}),
#  (u'AlabamaBirmingham', u'Louisville', {'weight': 1}),
#  (u'AlabamaBirmingham', u'Memphis', {'weight': 1}),
#  (u'AlabamaBirmingham', u'SouthernMississippi', {'weight': 1}),
#  (u'MiamiOhio', u'OhioState', {'weight': 1}),
#  (u'MiamiOhio', u'BallState', {'weight': 1}),
#  (u'MiamiOhio', u'BowlingGreenState', {'weight': 1}),
#  (u'MiamiOhio', u'EasternMichigan', {'weight': 1}),
#  (u'MiamiOhio', u'Vanderbilt', {'weight': 1}),
#  (u'MiamiOhio', u'Akron', {'weight': 1}),
#  (u'MiamiOhio', u'Ohio', {'weight': 1}),
#  (u'MiamiOhio', u'Buffalo', {'weight': 1}),
#  (u'MiddleTennesseeState', u'LouisianaMonroe', {'weight': 1}),
#  (u'MiddleTennesseeState', u'Florida', {'weight': 1}),
#  (u'MiddleTennesseeState', u'LouisianaLafayette', {'weight': 1}),
#  (u'MiddleTennesseeState', u'Maryland', {'weight': 1}),
#  (u'Maryland', u'WakeForest', {'weight': 1}),
#  (u'Maryland', u'FloridaState', {'weight': 1}),
#  (u'Maryland', u'NorthCarolina', {'weight': 1}),
#  (u'Maryland', u'Virginia', {'weight': 1}),
#  (u'Maryland', u'GeorgiaTech', {'weight': 1}),
#  (u'Maryland', u'WestVirginia', {'weight': 1}),
#  (u'Maryland', u'Temple', {'weight': 1}),
#  (u'Maryland', u'NorthCarolinaState', {'weight': 1}),
#  (u'Rice', u'Houston', {'weight': 1}),
#  (u'Rice', u'Michigan', {'weight': 1}),
#  (u'Rice', u'Hawaii', {'weight': 1}),
#  (u'Rice', u'TexasElPaso', {'weight': 1}),
#  (u'Rice', u'FresnoState', {'weight': 1}),
#  (u'Rice', u'Nevada', {'weight': 1}),
#  (u'Rice', u'Oklahoma', {'weight': 1}),
#  (u'Rice', u'SanJoseState', {'weight': 1}),
#  (u'SanJoseState', u'SouthernCalifornia', {'weight': 1}),
#  (u'SanJoseState', u'Nevada', {'weight': 1}),
#  (u'SanJoseState', u'Stanford', {'weight': 1}),
#  (u'SanJoseState', u'Hawaii', {'weight': 1}),
#  (u'SanJoseState', u'Nebraska', {'weight': 1}),
#  (u'SanJoseState', u'TexasElPaso', {'weight': 1}),
#  (u'SanJoseState', u'FresnoState', {'weight': 1}),
#  (u'NorthCarolinaState', u'WakeForest', {'weight': 1}),
#  (u'NorthCarolinaState', u'FloridaState', {'weight': 1}),
#  (u'NorthCarolinaState', u'NorthCarolina', {'weight': 1}),
#  (u'NorthCarolinaState', u'Virginia', {'weight': 1}),
#  (u'NorthCarolinaState', u'GeorgiaTech', {'weight': 1}),
#  (u'NorthCarolinaState', u'ArkansasState', {'weight': 1}),
#  (u'Arizona', u'SouthernCalifornia', {'weight': 1}),
#  (u'Arizona', u'OhioState', {'weight': 1}),
#  (u'Arizona', u'WashingtonState', {'weight': 1}),
#  (u'Arizona', u'ArizonaState', {'weight': 1}),
#  (u'Arizona', u'SanDiegoState', {'weight': 1}),
#  (u'Arizona', u'Utah', {'weight': 1}),
#  (u'Arizona', u'Stanford', {'weight': 1}),
#  (u'Arizona', u'UCLA', {'weight': 1}),
#  (u'Arizona', u'Oregon', {'weight': 1}),
#  (u'Wisconsin', u'OhioState', {'weight': 1}),
#  (u'Wisconsin', u'Northwestern', {'weight': 1}),
#  (u'Wisconsin', u'Iowa', {'weight': 1}),
#  (u'Wisconsin', u'Purdue', {'weight': 1}),
#  (u'Wisconsin', u'Michigan', {'weight': 1}),
#  (u'Wisconsin', u'Oregon', {'weight': 1}),
#  (u'Wisconsin', u'Hawaii', {'weight': 1}),
#  (u'Wisconsin', u'MichiganState', {'weight': 1}),
#  (u'Wisconsin', u'WesternMichigan', {'weight': 1}),
#  (u'Pittsburgh', u'PennState', {'weight': 1}),
#  (u'Pittsburgh', u'NorthCarolina', {'weight': 1}),
#  (u'Pittsburgh', u'BowlingGreenState', {'weight': 1}),
#  (u'Pittsburgh', u'Rutgers', {'weight': 1}),
#  (u'Pittsburgh', u'WestVirginia', {'weight': 1}),
#  (u'Pittsburgh', u'VirginiaTech', {'weight': 1}),
#  (u'Pittsburgh', u'MiamiFlorida', {'weight': 1}),
#  (u'Pittsburgh', u'Temple', {'weight': 1}),
#  (u'Pittsburgh', u'Syracuse', {'weight': 1}),
#  (u'Michigan', u'OhioState', {'weight': 1}),
#  (u'Michigan', u'PennState', {'weight': 1}),
#  (u'Michigan', u'Northwestern', {'weight': 1}),
#  (u'Michigan', u'Purdue', {'weight': 1}),
#  (u'Michigan', u'BowlingGreenState', {'weight': 1}),
#  (u'Michigan', u'MichiganState', {'weight': 1}),
#  (u'Michigan', u'UCLA', {'weight': 1}),
#  (u'Purdue', u'OhioState', {'weight': 1}),
#  (u'Purdue', u'PennState', {'weight': 1}),
#  (u'Purdue', u'CentralMichigan', {'weight': 1}),
#  (u'Purdue', u'Northwestern', {'weight': 1}),
#  (u'Purdue', u'MichiganState', {'weight': 1}),
#  (u'Oregon', u'SouthernCalifornia', {'weight': 1}),
#  (u'Oregon', u'WashingtonState', {'weight': 1}),
#  (u'Oregon', u'ArizonaState', {'weight': 1}),
#  (u'Oregon', u'UCLA', {'weight': 1}),
#  (u'Oregon', u'California', {'weight': 1}),
#  (u'Oregon', u'Nevada', {'weight': 1}),
#  (u'Oregon', u'Idaho', {'weight': 1}),
#  (u'Syracuse', u'EastCarolina', {'weight': 1}),
#  (u'Syracuse', u'MiamiFlorida', {'weight': 1}),
#  (u'Syracuse', u'BrighamYoung', {'weight': 1}),
#  (u'Syracuse', u'Rutgers', {'weight': 1}),
#  (u'Syracuse', u'WestVirginia', {'weight': 1}),
#  (u'Syracuse', u'VirginiaTech', {'weight': 1}),
#  (u'Syracuse', u'Buffalo', {'weight': 1}),
#  (u'Syracuse', u'Temple', {'weight': 1}),
#  (u'SouthernCalifornia', u'PennState', {'weight': 1}),
#  (u'SouthernCalifornia', u'WashingtonState', {'weight': 1}),
#  (u'SouthernCalifornia', u'Colorado', {'weight': 1}),
#  (u'SouthernCalifornia', u'Stanford', {'weight': 1}),
#  (u'SouthernCalifornia', u'ArizonaState', {'weight': 1}),
#  (u'SouthernCalifornia', u'UCLA', {'weight': 1}),
#  (u'SouthernCalifornia', u'California', {'weight': 1}),
#  (u'Northwestern', u'Iowa', {'weight': 1}),
#  (u'Northwestern', u'NorthernIllinois', {'weight': 1}),
#  (u'Northwestern', u'MichiganState', {'weight': 1}),
#  (u'SanDiegoState', u'AirForce', {'weight': 1}),
#  (u'SanDiegoState', u'ArizonaState', {'weight': 1}),
#  (u'SanDiegoState', u'BrighamYoung', {'weight': 1}),
#  (u'SanDiegoState', u'Utah', {'weight': 1}),
#  (u'SanDiegoState', u'ColoradoState', {'weight': 1}),
#  (u'SanDiegoState', u'NevadaLasVegas', {'weight': 1}),
#  (u'SanDiegoState', u'NewMexico', {'weight': 1}),
#  (u'Florida', u'Georgia', {'weight': 1}),
#  (u'Florida', u'FloridaState', {'weight': 1}),
#  (u'Florida', u'BallState', {'weight': 1}),
#  (u'Florida', u'Vanderbilt', {'weight': 1}),
#  (u'Florida', u'Kentucky', {'weight': 1}),
#  (u'Florida', u'Auburn', {'weight': 1}),
#  (u'Florida', u'Tennessee', {'weight': 1}),
#  (u'Florida', u'SouthCarolina', {'weight': 1}),
#  (u'BowlingGreenState', u'EasternMichigan', {'weight': 1}),
#  (u'BowlingGreenState', u'Temple', {'weight': 1}),
#  (u'BowlingGreenState', u'Akron', {'weight': 1}),
#  (u'BowlingGreenState', u'Ohio', {'weight': 1}),
#  (u'BowlingGreenState', u'Buffalo', {'weight': 1}),
#  (u'NewMexicoState', u'NorthTexas', {'weight': 1}),
#  (u'NewMexicoState', u'Georgia', {'weight': 1}),
#  (u'NewMexicoState', u'UtahState', {'weight': 1}),
#  (u'NewMexicoState', u'TexasElPaso', {'weight': 1}),
#  (u'NewMexicoState', u'ArkansasState', {'weight': 1}),
#  (u'NewMexicoState', u'NewMexico', {'weight': 1}),
#  (u'NewMexicoState', u'BoiseState', {'weight': 1}),
#  (u'NewMexicoState', u'Idaho', {'weight': 1}),
#  (u'NewMexicoState', u'SouthCarolina', {'weight': 1}),
#  (u'Baylor', u'NorthTexas', {'weight': 1}),
#  (u'Baylor', u'TexasA&M', {'weight': 1}),
#  (u'Baylor', u'Oklahoma', {'weight': 1}),
#  (u'Baylor', u'Nebraska', {'weight': 1}),
#  (u'Baylor', u'TexasTech', {'weight': 1}),
#  (u'MichiganState', u'OhioState', {'weight': 1}),
#  (u'MichiganState', u'PennState', {'weight': 1}),
#  (u'MichiganState', u'Iowa', {'weight': 1}),
#  (u'Ohio', u'CentralMichigan', {'weight': 1}),
#  (u'Ohio', u'WesternMichigan', {'weight': 1}),
#  (u'Ohio', u'Akron', {'weight': 1}),
#  (u'Ohio', u'Buffalo', {'weight': 1}),
#  (u'Buffalo', u'BallState', {'weight': 1}),
#  (u'Buffalo', u'NorthernIllinois', {'weight': 1}),
#  (u'Buffalo', u'Rutgers', {'weight': 1}),
#  (u'Buffalo', u'Akron', {'weight': 1}),
#  (u'SouthernMississippi', u'Houston', {'weight': 1}),
#  (u'SouthernMississippi', u'EastCarolina', {'weight': 1}),
#  (u'SouthernMississippi', u'Louisville', {'weight': 1}),
#  (u'SouthernMississippi', u'Tennessee', {'weight': 1}),
#  (u'SouthernMississippi', u'Alabama', {'weight': 1}),
#  (u'SouthernMississippi', u'Memphis', {'weight': 1}),
#  (u'WashingtonState', u'ArizonaState', {'weight': 1}),
#  (u'WashingtonState', u'Stanford', {'weight': 1}),
#  (u'WashingtonState', u'Utah', {'weight': 1}),
#  (u'WashingtonState', u'California', {'weight': 1}),
#  (u'WashingtonState', u'BoiseState', {'weight': 1}),
#  (u'WashingtonState', u'Idaho', {'weight': 1}),
#  (u'BoiseState', u'NorthTexas', {'weight': 1}),
#  (u'BoiseState', u'UtahState', {'weight': 1}),
#  (u'BoiseState', u'CentralMichigan', {'weight': 1}),
#  (u'BoiseState', u'Arkansas', {'weight': 1}),
#  (u'BoiseState', u'Idaho', {'weight': 1}),
#  (u'BoiseState', u'NewMexico', {'weight': 1}),
#  (u'BoiseState', u'ArkansasState', {'weight': 1}),
#  (u'WakeForest', u'Virginia', {'weight': 1}),
#  (u'WakeForest', u'FloridaState', {'weight': 1}),
#  (u'WakeForest', u'NorthCarolina', {'weight': 1}),
#  (u'WakeForest', u'Vanderbilt', {'weight': 1}),
#  (u'WakeForest', u'GeorgiaTech', {'weight': 1}),
#  (u'WakeForest', u'Navy', {'weight': 1}),
#  (u'NorthernIllinois', u'CentralMichigan', {'weight': 1}),
#  (u'NorthernIllinois', u'BallState', {'weight': 1}),
#  (u'NorthernIllinois', u'EasternMichigan', {'weight': 1}),
#  (u'NorthernIllinois', u'Auburn', {'weight': 1}),
#  (u'NorthernIllinois', u'WesternMichigan', {'weight': 1}),
#  (u'NorthernIllinois', u'Akron', {'weight': 1}),
#  (u'KansasState', u'NorthTexas', {'weight': 1}),
#  (u'KansasState', u'BallState', {'weight': 1}),
#  (u'KansasState', u'Iowa', {'weight': 1}),
#  (u'KansasState', u'Colorado', {'weight': 1}),
#  (u'KansasState', u'TexasA&M', {'weight': 1}),
#  (u'KansasState', u'Oklahoma', {'weight': 1}),
#  (u'KansasState', u'Nebraska', {'weight': 1}),
#  (u'KansasState', u'TexasTech', {'weight': 1}),
#  (u'WesternMichigan', u'CentralMichigan', {'weight': 1}),
#  (u'WesternMichigan', u'Iowa', {'weight': 1}),
#  (u'WesternMichigan', u'BallState', {'weight': 1}),
#  (u'WesternMichigan', u'EasternMichigan', {'weight': 1}),
#  (u'Navy', u'GeorgiaTech', {'weight': 1}),
#  (u'Navy', u'Rutgers', {'weight': 1}),
#  (u'Navy', u'Temple', {'weight': 1}),
#  (u'Navy', u'AirForce', {'weight': 1}),
#  (u'VirginiaTech', u'EastCarolina', {'weight': 1}),
#  (u'VirginiaTech', u'Virginia', {'weight': 1}),
#  (u'VirginiaTech', u'Rutgers', {'weight': 1}),
#  (u'VirginiaTech', u'WestVirginia', {'weight': 1}),
#  (u'VirginiaTech', u'Akron', {'weight': 1}),
#  (u'VirginiaTech', u'MiamiFlorida', {'weight': 1}),
#  (u'VirginiaTech', u'Temple', {'weight': 1}),
#  (u'UtahState', u'NorthTexas', {'weight': 1}),
#  (u'UtahState', u'ArizonaState', {'weight': 1}),
#  (u'UtahState', u'BrighamYoung', {'weight': 1}),
#  (u'UtahState', u'Utah', {'weight': 1}),
#  (u'UtahState', u'Idaho', {'weight': 1}),
#  (u'UtahState', u'TexasTech', {'weight': 1}),
#  (u'UtahState', u'ArkansasState', {'weight': 1}),
#  (u'Oklahoma', u'TexasA&M', {'weight': 1}),
#  (u'Oklahoma', u'Nebraska', {'weight': 1}),
#  (u'Oklahoma', u'TexasElPaso', {'weight': 1}),
#  (u'Oklahoma', u'TexasTech', {'weight': 1}),
#  (u'Oklahoma', u'ArkansasState', {'weight': 1}),
#  (u'GeorgiaTech', u'Georgia', {'weight': 1}),
#  (u'GeorgiaTech', u'FloridaState', {'weight': 1}),
#  (u'GeorgiaTech', u'NorthCarolina', {'weight': 1}),
#  (u'GeorgiaTech', u'Virginia', {'weight': 1}),
#  (u'Louisville', u'Houston', {'weight': 1}),
#  (u'Louisville', u'EastCarolina', {'weight': 1}),
#  (u'Louisville', u'FloridaState', {'weight': 1}),
#  (u'Louisville', u'Kentucky', {'weight': 1}),
#  (u'Arkansas', u'LouisianaMonroe', {'weight': 1}),
#  (u'Arkansas', u'Georgia', {'weight': 1}),
#  (u'Arkansas', u'Auburn', {'weight': 1}),
#  (u'Arkansas', u'Tennessee', {'weight': 1}),
#  (u'Arkansas', u'SouthCarolina', {'weight': 1}),
#  (u'Arkansas', u'Alabama', {'weight': 1}),
#  (u'Temple', u'EasternMichigan', {'weight': 1}),
#  (u'Temple', u'Rutgers', {'weight': 1}),
#  (u'Temple', u'WestVirginia', {'weight': 1}),
#  (u'Temple', u'MiamiFlorida', {'weight': 1}),
#  (u'BallState', u'CentralMichigan', {'weight': 1}),
#  (u'BallState', u'EasternMichigan', {'weight': 1}),
#  (u'Vanderbilt', u'Georgia', {'weight': 1}),
#  (u'Vanderbilt', u'Kentucky', {'weight': 1}),
#  (u'Vanderbilt', u'Auburn', {'weight': 1}),
#  (u'Vanderbilt', u'Tennessee', {'weight': 1}),
#  (u'Vanderbilt', u'SouthCarolina', {'weight': 1}),
#  (u'Vanderbilt', u'Alabama', {'weight': 1}),
#  (u'LouisianaLafayette', u'NorthTexas', {'weight': 1}),
#  (u'LouisianaLafayette', u'LouisianaMonroe', {'weight': 1}),
#  (u'LouisianaLafayette', u'TexasTech', {'weight': 1}),
#  (u'California', u'ArizonaState', {'weight': 1}),
#  (u'California', u'Utah', {'weight': 1}),
#  (u'California', u'Stanford', {'weight': 1}),
#  (u'California', u'UCLA', {'weight': 1}),
#  (u'California', u'FresnoState', {'weight': 1}),
#  (u'ColoradoState', u'Colorado', {'weight': 1}),
#  (u'ColoradoState', u'ArizonaState', {'weight': 1}),
#  (u'ColoradoState', u'BrighamYoung', {'weight': 1}),
#  (u'ColoradoState', u'Utah', {'weight': 1}),
#  (u'ColoradoState', u'NevadaLasVegas', {'weight': 1}),
#  (u'ColoradoState', u'NewMexico', {'weight': 1}),
#  (u'ColoradoState', u'Nevada', {'weight': 1}),
#  (u'ColoradoState', u'AirForce', {'weight': 1}),
#  (u'Akron', u'CentralMichigan', {'weight': 1}),
#  (u'FresnoState', u'OhioState', {'weight': 1}),
#  (u'FresnoState', u'UCLA', {'weight': 1}),
#  (u'FresnoState', u'Hawaii', {'weight': 1}),
#  (u'FresnoState', u'TexasElPaso', {'weight': 1}),
#  (u'FresnoState', u'Nevada', {'weight': 1}),
#  (u'Georgia', u'Kentucky', {'weight': 1}),
#  (u'Georgia', u'Tennessee', {'weight': 1}),
#  (u'Georgia', u'SouthCarolina', {'weight': 1}),
#  (u'Georgia', u'Auburn', {'weight': 1}),
#  (u'TexasA&M', u'Colorado', {'weight': 1}),
#  (u'TexasA&M', u'TexasTech', {'weight': 1}),
#  (u'TexasA&M', u'TexasElPaso', {'weight': 1}),
#  (u'FloridaState', u'BrighamYoung', {'weight': 1}),
#  (u'FloridaState', u'NorthCarolina', {'weight': 1}),
#  (u'FloridaState', u'Virginia', {'weight': 1}),
#  (u'FloridaState', u'MiamiFlorida', {'weight': 1}),
#  (u'Rutgers', u'MiamiFlorida', {'weight': 1}),
#  (u'Rutgers', u'WestVirginia', {'weight': 1}),
#  (u'NevadaLasVegas', u'NorthTexas', {'weight': 1}),
#  (u'NevadaLasVegas', u'AirForce', {'weight': 1}),
#  (u'NevadaLasVegas', u'BrighamYoung', {'weight': 1}),
#  (u'NevadaLasVegas', u'Utah', {'weight': 1}),
#  (u'NevadaLasVegas', u'Hawaii', {'weight': 1}),
#  (u'NevadaLasVegas', u'NewMexico', {'weight': 1}),
#  (u'NevadaLasVegas', u'Nevada', {'weight': 1}),
#  (u'PennState', u'OhioState', {'weight': 1}),
#  (u'PennState', u'Iowa', {'weight': 1}),
#  (u'LouisianaMonroe', u'Tennessee', {'weight': 1}),
#  (u'LouisianaMonroe', u'Memphis', {'weight': 1}),
#  (u'Colorado', u'Nebraska', {'weight': 1}),
#  (u'ArizonaState', u'Stanford', {'weight': 1}),
#  (u'ArizonaState', u'UCLA', {'weight': 1}),
#  (u'Memphis', u'Houston', {'weight': 1}),
#  (u'Memphis', u'EastCarolina', {'weight': 1}),
#  (u'Memphis', u'Tennessee', {'weight': 1}),
#  (u'Memphis', u'ArkansasState', {'weight': 1}),
#  (u'BrighamYoung', u'AirForce', {'weight': 1}),
#  (u'BrighamYoung', u'Utah', {'weight': 1}),
#  (u'BrighamYoung', u'Virginia', {'weight': 1}),
#  (u'BrighamYoung', u'NewMexico', {'weight': 1}),
#  (u'UCLA', u'Stanford', {'weight': 1}),
#  (u'UCLA', u'Alabama', {'weight': 1}),
#  (u'Auburn', u'Alabama', {'weight': 1}),
#  (u'Nevada', u'Hawaii', {'weight': 1}),
#  (u'Nevada', u'TexasElPaso', {'weight': 1}),
#  (u'ArkansasState', u'NorthTexas', {'weight': 1}),
#  (u'ArkansasState', u'Idaho', {'weight': 1}),
#  (u'EasternMichigan', u'CentralMichigan', {'weight': 1}),
#  (u'EasternMichigan', u'SouthCarolina', {'weight': 1}),
#  (u'SouthCarolina', u'Kentucky', {'weight': 1}),
#  (u'SouthCarolina', u'Tennessee', {'weight': 1}),
#  (u'SouthCarolina', u'Alabama', {'weight': 1}),
#  (u'MiamiFlorida', u'WestVirginia', {'weight': 1}),
#  (u'Idaho', u'NorthTexas', {'weight': 1}),
#  (u'Idaho', u'WestVirginia', {'weight': 1}),
#  (u'OhioState', u'Iowa', {'weight': 1}),
#  (u'Utah', u'AirForce', {'weight': 1}),
#  (u'Utah', u'NewMexico', {'weight': 1}),
#  (u'Virginia', u'NorthCarolina', {'weight': 1}),
#  (u'TexasElPaso', u'Hawaii', {'weight': 1}),
#  (u'TexasTech', u'NorthTexas', {'weight': 1}),
#  (u'TexasTech', u'Nebraska', {'weight': 1}),
#  (u'TexasTech', u'NewMexico', {'weight': 1}),
#  (u'NewMexico', u'AirForce', {'weight': 1}),
#  (u'EastCarolina', u'Houston', {'weight': 1}),
#  (u'EastCarolina', u'WestVirginia', {'weight': 1}),
#  (u'Kentucky', u'Tennessee', {'weight': 1}),
#  (u'Nebraska', u'Iowa', {'weight': 1}),
#  (u'Alabama', u'Tennessee', {'weight': 1})]

# %%
#https://stackoverflow.com/questions/15590812/networkx-convert-multigraph-into-simple-graph-with-weighted-edges
#I recommend anyone reading this, to snag the below function for converting multigraphs into simple graphs

#To calculate Eigenvector centrality; it may be necessary to combine multi-edges
#If say edge (0,1) existed twice; it can be converted to one edge, with a weight of two. 
for u,v,data in G.edges_iter(data=True):
    w = data['weight'] 
    if nG.has_edge(u,v):
        nG[u][v]['weight'] += w
    else:
        nG.add_edge(u, v, weight=w)

# %%
nG.nodes(data=True)
# Out:
# [(u'Mississippi',
#   {'centrality': 0.09649122807017543,
#    'id': 87,
#    'label': u'Mississippi',
#    'value': 9}),
#  (u'OregonState',
#   {'centrality': 0.08771929824561403,
#    'id': 108,
#    'label': u'OregonState',
#    'value': 8}),
#  (u'NotreDame',
#   {'centrality': 0.09649122807017543,
#    'id': 82,
#    'label': u'NotreDame',
#    'value': 5}),
#  (u'Wyoming',
#   {'centrality': 0.09649122807017543,
#    'id': 16,
#    'label': u'Wyoming',
#    'value': 7}),
#  (u'Minnesota',
#   {'centrality': 0.09649122807017543,
#    'id': 60,
#    'label': u'Minnesota',
#    'value': 2}),
#  (u'Illinois',
#   {'centrality': 0.09649122807017543,
#    'id': 64,
#    'label': u'Illinois',
#    'value': 2}),
#  (u'Kent',
#   {'centrality': 0.08771929824561403, 'id': 54, 'label': u'Kent', 'value': 6}),
#  (u'Toledo',
#   {'centrality': 0.07894736842105263,
#    'id': 85,
#    'label': u'Toledo',
#    'value': 6}),
#  (u'Indiana',
#   {'centrality': 0.09649122807017543,
#    'id': 106,
#    'label': u'Indiana',
#    'value': 2}),
#  (u'Clemson',
#   {'centrality': 0.08771929824561403,
#    'id': 103,
#    'label': u'Clemson',
#    'value': 0}),
#  (u'Texas',
#   {'centrality': 0.09649122807017543,
#    'id': 98,
#    'label': u'Texas',
#    'value': 3}),
#  (u'BostonCollege',
#   {'centrality': 0.09649122807017543,
#    'id': 29,
#    'label': u'BostonCollege',
#    'value': 1}),
#  (u'MississippiState',
#   {'centrality': 0.09649122807017543,
#    'id': 65,
#    'label': u'MississippiState',
#    'value': 9}),
#  (u'Tulsa',
#   {'centrality': 0.10526315789473684,
#    'id': 88,
#    'label': u'Tulsa',
#    'value': 11}),
#  (u'Kansas',
#   {'centrality': 0.08771929824561403,
#    'id': 52,
#    'label': u'Kansas',
#    'value': 3}),
#  (u'SouthernMethodist',
#   {'centrality': 0.10526315789473684,
#    'id': 53,
#    'label': u'SouthernMethodist',
#    'value': 11}),
#  (u'Connecticut',
#   {'centrality': 0.06140350877192982,
#    'id': 42,
#    'label': u'Connecticut',
#    'value': 5}),
#  (u'Tulane',
#   {'centrality': 0.09649122807017543,
#    'id': 86,
#    'label': u'Tulane',
#    'value': 4}),
#  (u'Duke',
#   {'centrality': 0.09649122807017543, 'id': 45, 'label': u'Duke', 'value': 0}),
#  (u'FresnoState',
#   {'centrality': 0.09649122807017543,
#    'id': 46,
#    'label': u'FresnoState',
#    'value': 11}),
#  (u'TexasChristian',
#   {'centrality': 0.09649122807017543,
#    'id': 110,
#    'label': u'TexasChristian',
#    'value': 4}),
#  (u'LouisianaState',
#   {'centrality': 0.08771929824561403,
#    'id': 96,
#    'label': u'LouisianaState',
#    'value': 9}),
#  (u'CentralFlorida',
#   {'centrality': 0.07017543859649122,
#    'id': 36,
#    'label': u'CentralFlorida',
#    'value': 5}),
#  (u'Cincinnati',
#   {'centrality': 0.09649122807017543,
#    'id': 92,
#    'label': u'Cincinnati',
#    'value': 4}),
#  (u'Missouri',
#   {'centrality': 0.08771929824561403,
#    'id': 102,
#    'label': u'Missouri',
#    'value': 3}),
#  (u'Washington',
#   {'centrality': 0.09649122807017543,
#    'id': 51,
#    'label': u'Washington',
#    'value': 8}),
#  (u'OklahomaState',
#   {'centrality': 0.08771929824561403,
#    'id': 107,
#    'label': u'OklahomaState',
#    'value': 3}),
#  (u'BrighamYoung',
#   {'centrality': 0.10526315789473684,
#    'id': 0,
#    'label': u'BrighamYoung',
#    'value': 7}),
#  (u'IowaState',
#   {'centrality': 0.09649122807017543,
#    'id': 72,
#    'label': u'IowaState',
#    'value': 3}),
#  (u'Army',
#   {'centrality': 0.09649122807017543, 'id': 91, 'label': u'Army', 'value': 4}),
#  (u'LouisianaTech',
#   {'centrality': 0.08771929824561403,
#    'id': 58,
#    'label': u'LouisianaTech',
#    'value': 11}),
#  (u'CentralMichigan',
#   {'centrality': 0.09649122807017543,
#    'id': 38,
#    'label': u'CentralMichigan',
#    'value': 6}),
#  (u'UCLA',
#   {'centrality': 0.09649122807017543, 'id': 21, 'label': u'UCLA', 'value': 8}),
#  (u'MiddleTennesseeState',
#   {'centrality': 0.07894736842105263,
#    'id': 63,
#    'label': u'MiddleTennesseeState',
#    'value': 10}),
#  (u'Maryland',
#   {'centrality': 0.09649122807017543,
#    'id': 109,
#    'label': u'Maryland',
#    'value': 0}),
#  (u'Rice',
#   {'centrality': 0.09649122807017543,
#    'id': 49,
#    'label': u'Rice',
#    'value': 11}),
#  (u'SanJoseState',
#   {'centrality': 0.09649122807017543,
#    'id': 73,
#    'label': u'SanJoseState',
#    'value': 11}),
#  (u'NorthCarolinaState',
#   {'centrality': 0.09649122807017543,
#    'id': 25,
#    'label': u'NorthCarolinaState',
#    'value': 0}),
#  (u'Arizona',
#   {'centrality': 0.09649122807017543,
#    'id': 22,
#    'label': u'Arizona',
#    'value': 8}),
#  (u'Wisconsin',
#   {'centrality': 0.10526315789473684,
#    'id': 15,
#    'label': u'Wisconsin',
#    'value': 2}),
#  (u'Pittsburgh',
#   {'centrality': 0.09649122807017543,
#    'id': 55,
#    'label': u'Pittsburgh',
#    'value': 1}),
#  (u'Michigan',
#   {'centrality': 0.09649122807017543,
#    'id': 32,
#    'label': u'Michigan',
#    'value': 2}),
#  (u'Stanford',
#   {'centrality': 0.09649122807017543,
#    'id': 77,
#    'label': u'Stanford',
#    'value': 8}),
#  (u'Oregon',
#   {'centrality': 0.09649122807017543,
#    'id': 68,
#    'label': u'Oregon',
#    'value': 8}),
#  (u'Syracuse',
#   {'centrality': 0.09649122807017543,
#    'id': 35,
#    'label': u'Syracuse',
#    'value': 1}),
#  (u'SouthernCalifornia',
#   {'centrality': 0.10526315789473684,
#    'id': 7,
#    'label': u'SouthernCalifornia',
#    'value': 8}),
#  (u'Northwestern',
#   {'centrality': 0.09649122807017543,
#    'id': 13,
#    'label': u'Northwestern',
#    'value': 2}),
#  (u'SanDiegoState',
#   {'centrality': 0.09649122807017543,
#    'id': 9,
#    'label': u'SanDiegoState',
#    'value': 7}),
#  (u'Florida',
#   {'centrality': 0.09649122807017543,
#    'id': 27,
#    'label': u'Florida',
#    'value': 9}),
#  (u'BowlingGreenState',
#   {'centrality': 0.09649122807017543,
#    'id': 31,
#    'label': u'BowlingGreenState',
#    'value': 6}),
#  (u'NewMexicoState',
#   {'centrality': 0.09649122807017543,
#    'id': 69,
#    'label': u'NewMexicoState',
#    'value': 10}),
#  (u'Baylor',
#   {'centrality': 0.08771929824561403,
#    'id': 10,
#    'label': u'Baylor',
#    'value': 3}),
#  (u'MichiganState',
#   {'centrality': 0.09649122807017543,
#    'id': 100,
#    'label': u'MichiganState',
#    'value': 2}),
#  (u'Ohio',
#   {'centrality': 0.08771929824561403, 'id': 71, 'label': u'Ohio', 'value': 6}),
#  (u'Buffalo',
#   {'centrality': 0.09649122807017543,
#    'id': 34,
#    'label': u'Buffalo',
#    'value': 6}),
#  (u'SouthernMississippi',
#   {'centrality': 0.08771929824561403,
#    'id': 75,
#    'label': u'SouthernMississippi',
#    'value': 4}),
#  (u'WashingtonState',
#   {'centrality': 0.09649122807017543,
#    'id': 78,
#    'label': u'WashingtonState',
#    'value': 8}),
#  (u'Nevada',
#   {'centrality': 0.10526315789473684,
#    'id': 67,
#    'label': u'Nevada',
#    'value': 11}),
#  (u'WakeForest',
#   {'centrality': 0.08771929824561403,
#    'id': 105,
#    'label': u'WakeForest',
#    'value': 0}),
#  (u'NorthernIllinois',
#   {'centrality': 0.08771929824561403,
#    'id': 12,
#    'label': u'NorthernIllinois',
#    'value': 6}),
#  (u'KansasState',
#   {'centrality': 0.10526315789473684,
#    'id': 3,
#    'label': u'KansasState',
#    'value': 3}),
#  (u'WesternMichigan',
#   {'centrality': 0.08771929824561403,
#    'id': 14,
#    'label': u'WesternMichigan',
#    'value': 6}),
#  (u'Navy',
#   {'centrality': 0.09649122807017543, 'id': 80, 'label': u'Navy', 'value': 5}),
#  (u'VirginiaTech',
#   {'centrality': 0.09649122807017543,
#    'id': 19,
#    'label': u'VirginiaTech',
#    'value': 1}),
#  (u'UtahState',
#   {'centrality': 0.07894736842105263,
#    'id': 90,
#    'label': u'UtahState',
#    'value': 5}),
#  (u'Oklahoma',
#   {'centrality': 0.09649122807017543,
#    'id': 84,
#    'label': u'Oklahoma',
#    'value': 3}),
#  (u'GeorgiaTech',
#   {'centrality': 0.09649122807017543,
#    'id': 37,
#    'label': u'GeorgiaTech',
#    'value': 0}),
#  (u'Louisville',
#   {'centrality': 0.08771929824561403,
#    'id': 57,
#    'label': u'Louisville',
#    'value': 4}),
#  (u'Arkansas',
#   {'centrality': 0.08771929824561403,
#    'id': 113,
#    'label': u'Arkansas',
#    'value': 9}),
#  (u'Temple',
#   {'centrality': 0.09649122807017543,
#    'id': 79,
#    'label': u'Temple',
#    'value': 1}),
#  (u'BallState',
#   {'centrality': 0.08771929824561403,
#    'id': 26,
#    'label': u'BallState',
#    'value': 6}),
#  (u'Vanderbilt',
#   {'centrality': 0.09649122807017543,
#    'id': 62,
#    'label': u'Vanderbilt',
#    'value': 9}),
#  (u'LouisianaLafayette',
#   {'centrality': 0.07017543859649122,
#    'id': 97,
#    'label': u'LouisianaLafayette',
#    'value': 10}),
#  (u'California',
#   {'centrality': 0.09649122807017543,
#    'id': 111,
#    'label': u'California',
#    'value': 8}),
#  (u'ColoradoState',
#   {'centrality': 0.08771929824561403,
#    'id': 41,
#    'label': u'ColoradoState',
#    'value': 7}),
#  (u'Akron',
#   {'centrality': 0.09649122807017543,
#    'id': 18,
#    'label': u'Akron',
#    'value': 6}),
#  (u'Memphis',
#   {'centrality': 0.09649122807017543,
#    'id': 66,
#    'label': u'Memphis',
#    'value': 4}),
#  (u'Georgia',
#   {'centrality': 0.08771929824561403,
#    'id': 95,
#    'label': u'Georgia',
#    'value': 9}),
#  (u'TexasA&M',
#   {'centrality': 0.09649122807017543,
#    'id': 81,
#    'label': u'TexasA&M',
#    'value': 3}),
#  (u'FloridaState',
#   {'centrality': 0.10526315789473684,
#    'id': 1,
#    'label': u'FloridaState',
#    'value': 0}),
#  (u'Rutgers',
#   {'centrality': 0.08771929824561403,
#    'id': 94,
#    'label': u'Rutgers',
#    'value': 1}),
#  (u'NevadaLasVegas',
#   {'centrality': 0.10526315789473684,
#    'id': 104,
#    'label': u'NevadaLasVegas',
#    'value': 7}),
#  (u'PennState',
#   {'centrality': 0.10526315789473684,
#    'id': 6,
#    'label': u'PennState',
#    'value': 2}),
#  (u'LouisianaMonroe',
#   {'centrality': 0.07017543859649122,
#    'id': 59,
#    'label': u'LouisianaMonroe',
#    'value': 10}),
#  (u'Colorado',
#   {'centrality': 0.09649122807017543,
#    'id': 40,
#    'label': u'Colorado',
#    'value': 3}),
#  (u'ArizonaState',
#   {'centrality': 0.09649122807017543,
#    'id': 8,
#    'label': u'ArizonaState',
#    'value': 8}),
#  (u'Marshall',
#   {'centrality': 0.08771929824561403,
#    'id': 99,
#    'label': u'Marshall',
#    'value': 6}),
#  (u'MiamiOhio',
#   {'centrality': 0.09649122807017543,
#    'id': 61,
#    'label': u'MiamiOhio',
#    'value': 6}),
#  (u'Auburn',
#   {'centrality': 0.09649122807017543,
#    'id': 17,
#    'label': u'Auburn',
#    'value': 9}),
#  (u'BoiseState',
#   {'centrality': 0.07894736842105263,
#    'id': 28,
#    'label': u'BoiseState',
#    'value': 11}),
#  (u'ArkansasState',
#   {'centrality': 0.08771929824561403,
#    'id': 24,
#    'label': u'ArkansasState',
#    'value': 10}),
#  (u'EasternMichigan',
#   {'centrality': 0.09649122807017543,
#    'id': 43,
#    'label': u'EasternMichigan',
#    'value': 6}),
#  (u'SouthCarolina',
#   {'centrality': 0.09649122807017543,
#    'id': 70,
#    'label': u'SouthCarolina',
#    'value': 9}),
#  (u'MiamiFlorida',
#   {'centrality': 0.08771929824561403,
#    'id': 101,
#    'label': u'MiamiFlorida',
#    'value': 1}),
#  (u'Idaho',
#   {'centrality': 0.07894736842105263,
#    'id': 50,
#    'label': u'Idaho',
#    'value': 10}),
#  (u'OhioState',
#   {'centrality': 0.09649122807017543,
#    'id': 47,
#    'label': u'OhioState',
#    'value': 2}),
#  (u'Utah',
#   {'centrality': 0.09649122807017543, 'id': 23, 'label': u'Utah', 'value': 7}),
#  (u'Virginia',
#   {'centrality': 0.08771929824561403,
#    'id': 33,
#    'label': u'Virginia',
#    'value': 0}),
#  (u'TexasElPaso',
#   {'centrality': 0.09649122807017543,
#    'id': 83,
#    'label': u'TexasElPaso',
#    'value': 11}),
#  (u'TexasTech',
#   {'centrality': 0.10526315789473684,
#    'id': 5,
#    'label': u'TexasTech',
#    'value': 3}),
#  (u'NewMexico',
#   {'centrality': 0.09649122807017543,
#    'id': 4,
#    'label': u'NewMexico',
#    'value': 7}),
#  (u'AlabamaBirmingham',
#   {'centrality': 0.08771929824561403,
#    'id': 112,
#    'label': u'AlabamaBirmingham',
#    'value': 4}),
#  (u'Purdue',
#   {'centrality': 0.09649122807017543,
#    'id': 39,
#    'label': u'Purdue',
#    'value': 2}),
#  (u'EastCarolina',
#   {'centrality': 0.09649122807017543,
#    'id': 44,
#    'label': u'EastCarolina',
#    'value': 4}),
#  (u'NorthCarolina',
#   {'centrality': 0.09649122807017543,
#    'id': 89,
#    'label': u'NorthCarolina',
#    'value': 0}),
#  (u'Hawaii',
#   {'centrality': 0.09649122807017543,
#    'id': 114,
#    'label': u'Hawaii',
#    'value': 11}),
#  (u'Kentucky',
#   {'centrality': 0.08771929824561403,
#    'id': 56,
#    'label': u'Kentucky',
#    'value': 9}),
#  (u'Nebraska',
#   {'centrality': 0.09649122807017543,
#    'id': 74,
#    'label': u'Nebraska',
#    'value': 3}),
#  (u'WestVirginia',
#   {'centrality': 0.09649122807017543,
#    'id': 30,
#    'label': u'WestVirginia',
#    'value': 1}),
#  (u'Iowa',
#   {'centrality': 0.10526315789473684, 'id': 2, 'label': u'Iowa', 'value': 2}),
#  (u'Alabama',
#   {'centrality': 0.09649122807017543,
#    'id': 20,
#    'label': u'Alabama',
#    'value': 9}),
#  (u'Houston',
#   {'centrality': 0.09649122807017543,
#    'id': 48,
#    'label': u'Houston',
#    'value': 4}),
#  (u'NorthTexas',
#   {'centrality': 0.08771929824561403,
#    'id': 11,
#    'label': u'NorthTexas',
#    'value': 10}),
#  (u'AirForce',
#   {'centrality': 0.08771929824561403,
#    'id': 93,
#    'label': u'AirForce',
#    'value': 7}),
#  (u'Tennessee',
#   {'centrality': 0.09649122807017543,
#    'id': 76,
#    'label': u'Tennessee',
#    'value': 9})]

# %%
nx.set_node_attributes(nG,'Eigen',eigenvector_centrality(nG))
nG.nodes(data=True)[1:4]
# Out:
# [(u'OregonState',
#   {'Eigen': 0.10099115080655272,
#    'centrality': 0.08771929824561403,
#    'id': 108,
#    'label': u'OregonState',
#    'value': 8}),
#  (u'NotreDame',
#   {'Eigen': 0.10091547519644511,
#    'centrality': 0.09649122807017543,
#    'id': 82,
#    'label': u'NotreDame',
#    'value': 5}),
#  (u'Wyoming',
#   {'Eigen': 0.10379164577225115,
#    'centrality': 0.09649122807017543,
#    'id': 16,
#    'label': u'Wyoming',
#    'value': 7})]

# %%
print nx.info(nG)
# Out:
# Name:
# Type: Graph
# Number of nodes: 115
# Number of edges: 613
# Average degree:  10.6609

# %%
dc=nx.degree_centrality(G)
dcs=sorted_map(dc)
dcs[:10]
# we can see that the first 10 teams that play 12 games also have the highest rank of degree centrality.
# It also proves that the node has more neighbors to connect, its degree will be higher. 
# teams who play 12 games not only play within their own conference, they may also play with other teams outside their conferences
# That’s the reason why they can have higher degree centrality because they not only connect with teams in their own conferences
# but they also can connect with teams outside their conferences.
# Out:
# [(u'BrighamYoung', 0.10526315789473684),
#  (u'FloridaState', 0.10526315789473684),
#  (u'Iowa', 0.10526315789473684),
#  (u'KansasState', 0.10526315789473684),
#  (u'Nevada', 0.10526315789473684),
#  (u'NevadaLasVegas', 0.10526315789473684),
#  (u'PennState', 0.10526315789473684),
#  (u'SouthernCalifornia', 0.10526315789473684),
#  (u'SouthernMethodist', 0.10526315789473684),
#  (u'TexasTech', 0.10526315789473684)]

# %%
h = plt.hist(dc.values())
plt.show(h)

# %%
ec=nx.eigenvector_centrality(G)
ecs=sorted_map(ec)
ecs[:10]
# Unlike the degree centrality, the eigenvector centrality is that a node is important if it is linked to by other important nodes.
# It means that a node with high degree centrality does not meant that it also has high eigenvector centrality.
# For example, BrighamYoung has the highest degree centrality, 
# but it does not have the highest eigenvector centrality accordingly.
# In this case, it means that Brigham Young may have games with other teams that do not have high eigenvector centrality as well. 
# Conversely, Nevada had the highest eigenvector centrality
# because it connected with other high eigenvector centrality teams and it also played the most number of game as well. 
# Nevada may played a lot of teams that made it to bowl games.
# Out:
# [(u'Nevada', 0.12768424714143733),
#  (u'SouthernMethodist', 0.12257733284057698),
#  (u'Tulsa', 0.1212895724623993),
#  (u'SouthernCalifornia', 0.1207252812631775),
#  (u'SanJoseState', 0.1199035354268502),
#  (u'FresnoState', 0.11956928362396661),
#  (u'Hawaii', 0.11769604360251928),
#  (u'Rice', 0.11724691716369856),
#  (u'TexasElPaso', 0.11647241977171086),
#  (u'Wisconsin', 0.11630296390411189)]

# %%
h = plt.hist(ec.values())
plt.show(h)

# %%
c=nx.closeness_centrality(G)
cs=sorted_map(c)
cs[:10]
# the more central the node is, the closer it is to all other nodes. 
# the higher closeness may show that the game may have more games with other teams in other conference group.
# For example, Louisiana Tech has the highest the closeness centrality. 
# we find out Louisiana Tech is in the conference of Western Athletic, and it only had 2 games with Hawaii and Tulsa in the Western Athletic. 
# each team had 7 games to 12 games so Louisiana Tech will have other 5 to 10 games with teams from other conference. 
# That’s the reason why Louisiana Tech has the highest closeness centrality.
# Out:
# [(u'LouisianaTech', 0.4367816091954023),
#  (u'Navy', 0.4351145038167939),
#  (u'Tulsa', 0.43018867924528303),
#  (u'Indiana', 0.42696629213483145),
#  (u'PennState', 0.4253731343283582),
#  (u'ArkansasState', 0.42379182156133827),
#  (u'BrighamYoung', 0.42379182156133827),
#  (u'Cincinnati', 0.42379182156133827),
#  (u'Wisconsin', 0.42379182156133827),
#  (u'Wyoming', 0.42379182156133827)]

# %%
h = plt.hist(c.values())
plt.show(h)

# %%
b=nx.betweenness_centrality(G)
bs=sorted_map(b)
bs[:10]
#nodes with high betweenness may have considerable influence within a network.
# In the football game, it means that the team play most of games with it neighbor within the same conference. 
# So the team such as Louisiana Tech may not have high betweenness since it only played 2 games within its conference.
# Out:
# [(u'NotreDame', 0.03353295672662948),
#  (u'BrighamYoung', 0.03248994918389482),
#  (u'Navy', 0.02916105326422372),
#  (u'LouisianaTech', 0.028822823420770936),
#  (u'CentralMichigan', 0.025186801970868814),
#  (u'NewMexicoState', 0.024139419776449258),
#  (u'Cincinnati', 0.023836354939100652),
#  (u'KansasState', 0.023070098856845606),
#  (u'Alabama', 0.023046321730608013),
#  (u'Wyoming', 0.022213447427560148)]

# %%
h = plt.hist(b.values())
plt.show(h)

# %%
totalEigen=0
for k,v in nG.nodes_iter(data=True):
    totalEigen += v['Eigen']
avg_Eigen = totalEigen/len(nG.nodes())
avg_Eigen
# Out:
# 0.09176640041543295

# %%
def get_nodes_by_attr(graph,attr,val):
    nBunch = {}
    #if include_node_data == True:
        
    for knowd,data in graph.nodes_iter(data=True):
        if data[attr] == val:
            nBunch[knowd] = data
        else:
            pass
    return nBunch

# %%
each_category_by_node_bunch = [0]*12
count = 0
for label in each_category_by_node_bunch:
    each_category_by_node_bunch[count] = get_nodes_by_attr(nG,'value',count)
    count +=1

# %%
centralities_per_conference = []
for category in each_category_by_node_bunch:
    totalCent = 0
    for u in category.itervalues():
        totalCent += u['centrality']
    centralities_per_conference.append(totalCent/len(category))

# %%
centralities_per_conference
# Out:
# [0.09454191033138401,
#  0.09429824561403508,
#  0.09888357256778307,
#  0.09502923976608187,
#  0.093859649122807,
#  0.0807017543859649,
#  0.09109311740890688,
#  0.09649122807017543,
#  0.09649122807017542,
#  0.0935672514619883,
#  0.08145363408521303,
#  0.09649122807017542]

# %%
average_centrality = reduce(lambda x, y: x + y, centralities_per_conference) / len(centralities_per_conference)

# %%
average_centrality
# Out:
# 0.09274183824622421
