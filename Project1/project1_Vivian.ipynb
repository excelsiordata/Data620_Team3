# %%
from networkx import *
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import networkx as nx
url="http://www-personal.umich.edu/~mejn/netdata/football.zip"

import urllib
import io
import zipfile

football = urllib.urlopen(url)  # open URL
f=io.BytesIO(football.read()) # read into BytesIO "file"
football.close()

zf = zipfile.ZipFile(f) # zipfile object
txt=zf.read('football.txt').decode() # read info file
gml=zf.read('football.gml').decode() # read gml data
# throw away bogus first line with # from mejn files
gml=gml.split('\n')[1:]
G=parse_gml(gml) # parse gml data


print(txt)
# print degree for each team - number of games
# Out:
# The file football.gml contains the network of American football games
# between Division IA colleges during regular season Fall 2000, as compiled
# by M. Girvan and M. Newman.  The nodes have values that indicate to which
# conferences they belong.  The values are as follows:
#
#   0 = Atlantic Coast
#   1 = Big East
#   2 = Big Ten
#   3 = Big Twelve
#   4 = Conference USA
#   5 = Independents
#   6 = Mid-American
#   7 = Mountain West
#   8 = Pacific Ten
#   9 = Southeastern
#  10 = Sun Belt
#  11 = Western Athletic
#
# If you make use of these data, please cite M. Girvan and M. E. J. Newman,
# Community structure in social and biological networks,
# Proc. Natl. Acad. Sci. USA 99, 7821-7826 (2002).
#
# Correction: Two edges were erroneously duplicated in this data set, and
# have been removed (21 SEP 2014)

# %%
df = pd.DataFrame(G.node)
df.ix['value'].unique()
# Out:
# /Users/vivian/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
# array([7, 6, 9, 4, 8, 10, 3, 11, 1, 5, 0, 2], dtype=object)

# %%
df.head()
# Out:
#        AirForce  Akron  Alabama  AlabamaBirmingham  Arizona  ArizonaState  \
# id           93     18       20                112       22             8
# label  AirForce  Akron  Alabama  AlabamaBirmingham  Arizona  ArizonaState
# value         7      6        9                  4        8             8
#
#        Arkansas  ArkansasState  Army  Auburn   ...     Vanderbilt  Virginia  \
# id          113             24    91      17   ...             62        33
# label  Arkansas  ArkansasState  Army  Auburn   ...     Vanderbilt  Virginia
# value         9             10     4       9   ...              9         0
#
#        VirginiaTech  WakeForest  Washington  WashingtonState  WestVirginia  \
# id               19         105          51               78            30
# label  VirginiaTech  WakeForest  Washington  WashingtonState  WestVirginia
# value             1           0           8                8             1
#
#        WesternMichigan  Wisconsin  Wyoming
# ...

# %%
edges_df = pd.DataFrame(G.edge)
edges_df.head()
# Out:
#                   AirForce Akron Alabama AlabamaBirmingham Arizona  \
# AirForce               NaN   NaN     NaN               NaN     NaN
# Akron                  NaN   NaN     NaN               NaN     NaN
# Alabama                NaN   NaN     NaN               NaN     NaN
# AlabamaBirmingham      NaN   NaN     NaN               NaN     NaN
# Arizona                NaN   NaN     NaN               NaN     NaN
#
#                   ArizonaState Arkansas ArkansasState Army Auburn   ...    \
# AirForce                   NaN      NaN           NaN   {}    NaN   ...
# Akron                      NaN      NaN           NaN  NaN    NaN   ...
# Alabama                    NaN       {}           NaN  NaN     {}   ...
# AlabamaBirmingham          NaN      NaN           NaN   {}    NaN   ...
# Arizona                     {}      NaN           NaN  NaN    NaN   ...
#
#                   Vanderbilt Virginia VirginiaTech WakeForest Washington  \
# ...

# %%
# Before we find the degree centrality, we want to find degree of each node.
for n,d in G.degree_iter():
    print('%s %d' % (n, d))
# Out:
# Mississippi 11
# OregonState 10
# NotreDame 11
# Wyoming 11
# Minnesota 11
# Illinois 11
# Kent 10
# Toledo 9
# Indiana 11
# Clemson 10
# Texas 11
# BostonCollege 11
# MississippiState 11
# Tulsa 12
# Kansas 10
# SouthernMethodist 12
# Connecticut 7
# Tulane 11
# Duke 11
# Missouri 10
# TexasChristian 11
# LouisianaState 10
# CentralFlorida 8
# Cincinnati 11
# Washington 11
# OklahomaState 10
# Marshall 10
# IowaState 11
# Army 11
# LouisianaTech 10
# AlabamaBirmingham 10
# MiamiOhio 11
# MiddleTennesseeState 9
# Maryland 11
# Rice 11
# SanJoseState 11
# NorthCarolinaState 11
# Arizona 11
# Wisconsin 12
# Pittsburgh 11
# Michigan 11
# Purdue 11
# Oregon 11
# Syracuse 11
# SouthernCalifornia 12
# Northwestern 11
# SanDiegoState 11
# Florida 11
# BowlingGreenState 11
# NewMexicoState 11
# Baylor 10
# MichiganState 11
# Ohio 10
# Buffalo 11
# SouthernMississippi 10
# WashingtonState 11
# BoiseState 9
# WakeForest 10
# NorthernIllinois 10
# KansasState 12
# WesternMichigan 10
# Navy 11
# ...

# %%
deg=net.degree(G)
min(deg.values())
# Out:
# 7

# %%
max (deg.values())
# Out:
# 12

# %%
degree_of_nodes = degree_centrality(G)
for key, value in sorted(degree_of_nodes.iteritems(), key=lambda (k,v): (v,k), reverse = True):
    print "%s %s" % (key, value)
# Out:
# Wisconsin 0.105263157895
# Tulsa 0.105263157895
# TexasTech 0.105263157895
# SouthernMethodist 0.105263157895
# SouthernCalifornia 0.105263157895
# PennState 0.105263157895
# NevadaLasVegas 0.105263157895
# Nevada 0.105263157895
# KansasState 0.105263157895
# Iowa 0.105263157895
# FloridaState 0.105263157895
# BrighamYoung 0.105263157895
# Wyoming 0.0964912280702
# WestVirginia 0.0964912280702
# WashingtonState 0.0964912280702
# Washington 0.0964912280702
# VirginiaTech 0.0964912280702
# Vanderbilt 0.0964912280702
# Utah 0.0964912280702
# UCLA 0.0964912280702
# Tulane 0.0964912280702
# TexasElPaso 0.0964912280702
# TexasChristian 0.0964912280702
# TexasA&M 0.0964912280702
# Texas 0.0964912280702
# Tennessee 0.0964912280702
# Temple 0.0964912280702
# Syracuse 0.0964912280702
# Stanford 0.0964912280702
# SouthCarolina 0.0964912280702
# SanJoseState 0.0964912280702
# SanDiegoState 0.0964912280702
# Rice 0.0964912280702
# Purdue 0.0964912280702
# Pittsburgh 0.0964912280702
# ...
